# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
from urllib.request import HTTPError
import csv
from datetime import datetime

html = urlopen('https://www.batteryjunction.com/')
soup = BeautifulSoup(html, 'html.parser')

def get_all_links():
    all_links = []
    categories = soup.find_all('ul', {"class": "categories"})
    for links in categories:
        a_tag = links.find_all('a')
        for href in a_tag:
            all_links.append(href.get('href'))
    return all_links;

def collect_data():
    links = get_all_links()
    for link in links:
        html = urlopen('https://www.batteryjunction.com/'+link)
        soup = BeautifulSoup(html, 'html.parser')
        name_and_price = soup.find_all('div', {"class" : "details"})

        for item in name_and_price:
            name = item.find('h2').text
            link = item.find('a')
            link = link.get('href')
            price = item.find('div', {"class": "price"})
            price = price.text
            print(name, price, link)
            with open('products.csv', 'a') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([name, price, link, datetime.now()])
        
collect_data()
# Out:
# Klarus Mi7 Mini-Might EDC Flashlight - CREE XP-L HI V3 LED - 700 Lumens - Includes 1 x AA and 1 x 14500 - 7 Colors
#
# $39.95
#                  klarus-mi7-mini-flashlight.html
#
# Klarus Mi7 Ti Mini-Might Titanium EDC Flashlight - CREE XP-L HI V3 LED - 700 Lumens - Includes 1 x AA and 1 x 14500 - Limited Time Offer!
#
# $64.95
#                  klarus-mi7-ti-flashlight.html
#
# Klarus XT11 Flashlight - CREE XM-L2-U2 LED - 1060 Lumens - Uses 2 x CR123A  or 1 x 18650 (Included) - Now with an Additional Free Battery!
#
# $69.95
#                  klarus-xt11-xml2-u2-opt.html
#
# Klarus ST15 Multi-Function Dual Switch Flashlight - CREE XP-L-HI V3 LED - 1100 Lumens - Now with Micro-USB 18650!
#
# $49.95
#                  klarus-st15.html
#
# Klarus XT12S Rechargeable LED Flashlight - CREE XHP35 HI D4 - 1600 Lumens - Uses 1 x 18650 (included) or 2 x CR123A
#
# $73.91
#                  klarus-xt12s-rechargeable-tactical-led-flashlight.html
#
# Fenix ALG-01 Tactical Flashlight Ring
#
# $12.95
#                  fenix-alg-01.html
#
# Fenix AR101 Remote Pressure Switch for TK Series LED Flashlights - Works with TK10 - TK11-Q5 - TK11-R2 and TK20
#
# $8.37
#                  fenix-t-pressure.html
#
# Fenix Flashlights Filters (Blue & Red) for TK Series: TK10, TK11 & TK20
#
# $4.80
#                  fenix-tk-red.html
#
# Fenix Flashlights FX-RTF Red Filter fits most Pxx and Lxx series Fenix LED Flashlights (AD301-R)
#
# $4.00
#                  fenix-fx-rtf.html
#
# JETBeam RM-46 Weapon Rail Mount for Raptor RRT-3 Flashlight - Fits Picatinny Rails - Black
#
# $66.00
#                  jetbeam-3-rail-mount.html
#
# JETBeam FSG34 Green Filter - 1.44 Inch Diameter - Fits JETBeam III M, RRT2 and PC25 Flashlights
#
# $6.00
#                  jetbeam-fsg34.html
#
# JETBeam GM-02 Weapon Mount / RM01 Picatinny Rail Mount - Fits 1 Inch Diameter Flashlights, Including JETBeam Raptor RRT-2
#
# $14.00
#                  jetbeam-gm-02-gun-mount.html
#
# Klarus TR11 Remote Pressure Switch for XT1A - XT2A and XT1C Model Flashlights
#
# $13.56
#                  klarus-tr11-remote-switch.html
#
# Klarus TR12 Remote Pressure Switch for XT2C Flashlight
#
# $13.56
#                  klarus-tr12-remote-switch.html
#
# Olight Blue Filter for M31, M3X,and SR50 LED Flashlights
#
# $15.00
#                  olight-filter-m31-blue.html
#
# Olight Blue Filter - Fits the Olight M20, S35 and S65 LED Flashlights
#
# $10.00
#                  olight-m20-blue-filter.html
#
# Olight Green Filter - Fits the Olight M20 LED Flashlights
#
# $10.00
#                  olight-m20-green-filter.html
#
# Olight Red Filter - Fits the Olight M20 LED Flashlights
#
# $10.00
#                  olight-m20-red-filter.html
#
# Olight M30 Blue Filter For M30 Flashlights
#
# $5.50
#                  olight-m30-blue-filter.html
#
# Olight Green Filter for M30 Series LED Flashlights
#
# $10.00
#                  olight-m30-green-filter.html
#
# Olight Red Filter for M30 Series LED Flashlights
#
# $5.50
#                  olight-m30-red-filter.html
#
# Olight Coiled Remote Pressure Switch for T20-T and T-20M Tactical Series Flashlights
#
# $10.00
#                  olight-t20-switch-coiled.html
#
# PowerTac Offset Weapon Mount for the Cadet Flashlight
#
# $14.95
#                  powertac-mount.html
#
# PowerTac Remote Pressure Switch for Cadet Flashlight
#
# $15.95
#                  powertac-pressure.html
#
# PowerTac Pressure Switch for Gladiator and Warrior Flashlights
#
# $15.95
#                  powertac-warrior-gladiator-switch.html
#
# Streamlight Contour Remote (Fits Glock 17/22 and 19/23 Size Frames)
#
# $37.95
#                  streamlight-69300.html
#
# Nitecore RSW1 Remote Pressure Switch for MT2C - MT25 - MT26 - MT40 - MH2C - MH25 - MH40 - P12, P25, SRT6, and SRT7 flashlights
#
# $17.90
#                  nitecore-rsw1.html
#
# Spotlight Turbo Light Color Cap (SPOT-9006)
#
# $5.35
#                  spotlight-9006.html
#
# Nitecore 23mm Blue Filter - Works with MT1A, MT2A & MT1C
#
# $3.95
#                  nitecore-nfb23.html
#
# Nitecore 25.4mm Filters - Choose Red, Green, Blue or White Diffuser - Works with MT2C, MH1A, MH2A, MH1C, MH2C, P12, P10, EC1, EC2, EA1 & EA2
#
# $3.95
#                  nitecore-nf25mm-opt.html
#
# Nitecore 23mm Green Filter - Works with MT1A, MT2A & MT1C
#
# $3.95
#                  nitecore-nfg23.html
#
# Nitecore 34mm Green Filter - Works with MT25, MT26, EA45S & EC25
#
# $4.95
#                  nitecore-nfg34.html
#
# Nitecore 60mm Green Filter - Works with TM11, TM15 & MH40
#
# $13.50
#                  nitecore-nfg60.html
#
# Nitecore 23mm Red Filter - Works with MT1A, MT2A & MT1C
#
# $3.95
#                  nitecore-nfr23.html
#
# Nitecore 34mm Red Filter - Works with MT25, MT26, EA45S & EC25
#
# $4.95
#                  nitecore-nfr34.html
#
# Nitecore 40mm Filters - Choose Red, Green, Blue or White Diffuser - Works with MH25, MH27, P16 & EA4
#
# $6.80
#                  nitecore-nf40mm-opt.html
#
# Nitecore 60mm Red Filter - Works with TM11, TM15 & MH40
#
# $13.50
#                  nitecore-nfr60.html
#
# Olight Second Generation Magnetic X Weapon Mount (X-WM02) Fits Olight M20, M3X, M20S, M20SX, M21X, and M22 LED Flashlights
#
# $21.99
#                  olight-x-wm02.html
#
# Olight Green Filter - Fits the Olight M10 and M18 LED Flashlights (OLIGHT-FM10-G)
#
# $10.00
#                  olight-fm10-g.html
#
# Olight Red Filter - Fits the Olight M10 and M18 LED Flashlights (OLIGHT-FM10-R)
#
# $10.00
#                  olight-fm10-r.html
#
# Olight Blue Filter - Fits the Olight M10 and M18 LED Flashlights (OLIGHT-FM10-B)
#
# $10.00
#                  olight-fm10-b.html
#
# Olight RM20S Remote Pressure Switch - Fits the M22 and M20SX-L2 Flashlights
#
# $15.00
#                  olight-rm20s.html
#
# The Mako Group - FAB Defense 1" Tactical Flashlight Mount - Quick Release PLA1
#
# $23.95
#                  fab-defense-pla1.html
#
# The Mako Group - FAB Defense 1 1/8" Tactical Flashlight Mount - Quick Release  PLA118
#
# $25.25
#                  fab-defense-pla118.html
#
# The Mako Group - FAB Defense 3/4" Tactical Flashlight Mount - Quick Release PLA34
#
# $21.25
#                  fab-defense-pla34.html
#
# The Mako Group - FAB Defense 1" Tactical Flashlight Mount - Quick Release PLG
#
# $29.30
#                  fab-defense-plg.html
#
# The Mako Group - FAB Defense 1" Tactical Flashlight Mount - Quick Release PLS-1
#
# $29.35
#                  fab-defense-pls-1.html
#
# The Mako Group - FAB Defense Tactical Foregrip with 1" Flashlight adapter and On/Off Trigger T-GRIP
#
# $79.20
#                  fab-defense-t-grip.html
#
# Nitecore GM02 Picatinny Rail Flashlight Mount - Fits Nitecore SRT6, SRT7, MT2C, MT25, MT26, MT40, MH25, and MH40 flashlights
#
# $18.00
#                  nitecore-gm02.html
#
# Niteye TTS01 Remote Pressure Switch for the TF/TR/TS Series Flashlights
#
# $18.00
#                  niteye-tts01.html
#
# Ledlenser Filter Set -Includes Red- Green- Blue- and Yellow Filters (Ledlenser 880009)
#
# $4.49
#                  led-lenser-880009.html
#
# PowerTac Filter For Warrior and Hero Flashlights - Red or Green Options
#
# $11.95
#                  powertac-fil-rw-opt.html
#
# PowerTac Filters for Spartacus LED Flashlight - Red or Green Options
#
# $14.99
#                  powertac-fil-rs-opt.html
#
# JETBeam MFD34 Red Filter - 1.34 Inches - Fits JETBeam IIIM 3M - RRT2 - PC25 - BC25 - RRT21 - TF20 Flashlights
#
# $5.95
#                  jetbeam-mfr34.html
#
# JETBeam MFG34 Green Filter - 1.34 Inches - Fits JETBeam IIIM 3M - RRT2 - PC25 - BC25 - RRT21 - TF20 Flashlights
#
# $5.95
#                  jetbeam-mfg34.html
#
# JETBeam MFB34 Blue Filter - 1.34 Inch Diameter - Fits JETBeam IIIM 3M - RRT2 - PC25 - BC25 - RRT21 - TF20 Flashlights
#
# $5.95
#                  jetbeam-mfb34.html
#
# JETBeam MFD38 Red Filter - 1.50 Inches - Fits JETBeam DDC25 - DDR26 - TR20 -TS20 Flashlights
#
# $6.95
#                  jetbeam-mfr38.html
#
# JETBeam MFB38 Blue Filter - 1.50 Inches- Fits JETBeam DDC25 - DDR26 - TR20 -TS20 Flashlights
#
# $6.95
#                  jetbeam-mfb38.html
#
# JETBeam GM03 Weapon Mount for JETBeam 3M IIIM RRT2 RRT15 RRT21 BC20 BC25 BC40 PC20 PC25 ST DDC25 DDR26 Niteye EYE25 TR20 TS20 TF Series
#
# $10.00
#                  jetbeam-gm03.html
#
# Olight WM25 Offset Weapon Mount - Fits the M22, M3X, M21X, and M20SX Flashlights
#
# $16.95
#                  olight-wm25.html
#
# Olight Red Filter for M22, S80, R40 LED Flashlights
#
# $10.00
#                  olight-fm21-red-filter.html
#
# Olight Green Filter for M22, S80, R40 LED Flashlights
#
# $10.00
#                  olight-fm21-green-filter.html
# Olight Blue Filter for M22, S80, R40 LED Flashlights
#
# $10.00
#                  olight-fm21-blue-filter.html
#
# JETBeam Color Filter - 1.46 Inches - Fits JETBeam 3M Pro Flashlight - Red, Blue or Green
#
# $7.00
#                  jetbeam-mf-opt.html
#
# Klarus FT30 Filter - Available in Red, Green or Blue
#
# $11.95
#                  klarus-ft30-opt.html
#
# Klarus FT11 Filter - Available in Red, Green, Blue or White
#
# $5.95
#                  klarus-ft-opt.html
#
# Fenix Filter Adapter for PD35, PD12, and UC40 UE - Available in Red, Green and Blue
#
# $4.50
#                  fenix-aof-splus-opt.html
#
# LRI Accessory Kit:  Photon Clip - Necklace - Long Neck Lanyard - 1 CR2032 and 2 CR2016 Batteries -  1 Screw - Screwdriver and 2 Velcro Brand Dot Sets (AK)
#
# $8.71
#                  lri-ak.html
#
# Klarus Metal Picatinny Gun Mount-3 - Fits XT10, XT11, XT20 & XT30 Model Flashlights (MGM-4)
#
# $12.50
#                  klarus-mgm4.html
#
# JETBeam RM-03 Remote Pressure Switch for JETBeam RRT-3 Flashlight
#
# $8.00
#                  jetbeam-rrt-3-remote.html
#
# Olight FSR51 Filter - Green, Red, Blue or White - Fits M2X-UT, M3X, SR51, SR52
#
# $15.00
#                  olight-filter-fsr51-opt.html
#
# Fenix AER-03 Remote Switch - For use with TK16/TK32 2015 flashlights
#
# $19.95
#                  fenix-aer-03.html
#
# Olight RM30 Remote Pressure Switch for M30/M20S
#
# $15.00
#                  olight-rm30.html
#
# Klarus TR10 Remote Pressure Switch for XT10, XT11, XT12, XT20, XT30, XTQ1, and XTQ2 Flashlights
#
# $16.95
#                  klarus-tr10-remote-switch.html
#
# Olight RM23 Tactical Remote Switch for the M23 and the M3XS-UT
#
# $15.99
#                  olight-rm23.html
#
# Nitecore Chameleon CR6 Red LED Flashlight - CREE XM-L2 & CREE XP-G2 R5 - 440 Lumens - Uses 2 x CR123A or 1 x 18650
#
# $69.95
#                  nitecore-cr6-xpg2-smo.html
#
# Nitecore Chameleon CG6 Green LED Flashlight - CREE XP-G2 R5 & CREE XP-E G2 - 440 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $69.95
#                  nitecore-cg6-xpg2-smo.html
#
# Nitecore Chameleon CB6 Blue LED Flashlight - CREE XP-G2 R5 & CREE XP-E (D4) - 440 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $69.95
#                  nitecore-cb6-xpg2-smo.html
#
# Nitecore Chameleon CU6 Ultraviolet LED Flashlight - CREE XP-G2 R5 & CREE XP-E R2 - 440 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $109.95
#                  nitecore-cu6-xpg2-smo.html
#
# Nitecore Chameleon CB6 Blue LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Remote Switch, 18650 Battery and Charger -  Fits Picatinny Railed Guns - 440 Lumens
#
# $139.00
#                  nitecore-cb6-hunting-kit.html
#
# Nitecore Chameleon CG6 Night Hunting Kit - CG6 LED Flashlight - 440 Lumens - with Pressure Switch, Battery Charger, Car Adapter and 18650
#
# $129.00
#                  nitecore-cg6-hunting-kit.html
#
# Nitecore Chameleon CR6 Red LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Remote Switch, 18650 Battery and Charger -  Fits Picatinny Railed Guns - 440 Lumens
#
# $129.00
#                  nitecore-cr6-hunting-kit.html
#
# Nitecore Chameleon CU6 UV Ultraviolet LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Remote Switch, 18650 Battery and Charger -  Fits Picatinny Railed Guns - 440 Lumens
#
# $189.00
#                  nitecore-cu6-hunting-kit.html
#
# Smith and Wesson Galaxy Pro Flashlight with CREE XPG2-R5 LED - 330 Lumens - Uses 4 x AA (SW4AACR)
#
# $33.85
#                  smith-wesson-sw4aacr.html
#
# JETBeam RRT26 Rapid Response Tactical Flashlight with Red, Green and Blue LEDs - CREE XP-L LED - 1080 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $107.95
#                  jetbeam-rrt26-xpl.html
#
# Ledlenser T2QC Quad-Color LED Flashlight - 140 Lumens - Uses 3 x AAA Batteries
#
# $30.00
#                  led-lenser-880291.html
#
# Nitecore Multitask Hybrid MH27 USB Rechargeable Tactical Flashlight - CREE XP-L HI V3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123As
#
# $89.95
#                  nitecore-mh27.html
#
# Fenix TK76 Tactical Flashlight - 3 x CREE XM-L2 U2 LEDs - 2800 Lumens - Uses 4 x 18650s or 8 x CR123As
#
# $239.96
#                  fenix-tk76-xml2.html
#
# Fenix TK41C High Output Tri-Color Tactical Flashlight - CREE XM-L2 U2 / Philips Luxeon Z LEDs - 1000 Lumens - Uses 8 x AAs
#
# $99.95
#                  fenix-tk41c.html
#
# Fenix TK25 IR LED Flashlight - CREE XP-G2 S3 - 850nm IR - 1000 lumens - Uses 1x 18650 or 2x CR123A
#
# $99.95
#                  fenix-tk25-ir-infrared-led-flashlight.html
#
# Fenix TK32 (2016) Tactical Flashlight - CREE XP-L HI V3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123As
#
# $94.95
#                  fenix-tk32-2016.html
#
# Nitecore Multitask Hybrid MH25GT Flashlight Hunting Kit with Gun Mount, RSW1 Pressure Switch, Filters and Holster - CREE XP-L HI V3 LED - 1000 Lumens - Uses 1 x 18650 (Included) or 2 x CR123A
#
# $120.00
#                  nitecore-mh25gt-hunting-kit.html
#
# Nitecore MH27 1000 Lumen LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Pressure Switch, NFR40 Red Filter, NFG40 Green Filter - Fits Picatinny Railed Guns
#
# $129.00
#                  nitecore-mh27-hunting-kit.html
#
# Nitecore MH40GT 1000 Lumen LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Pressure Switch, NFR60 Red Filter, NFG60 Green Filter - Fits Picatinny Railed Guns
#
# $169.00
#                  nitecore-mh40gt-hunting-kit.html
#
# Nitecore Multitask MT25 Hunting Flashlight with Charger, Filters, Pressure Switch, Gun Mount & Car Adapter - CREE XP-G R5 LED - 390 Lumens - Uses 1 x 18650 (Included) or 2 x CR123A
#
# $120.00
#                  nitecore-mt25-hunting-kit.html
#
# Nitecore P16 960 Lumen LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Pressure Switch, NFR60 Red Filter, NFG60 Green Filter - Fits Picatinny Railed Guns
#
# $139.00
#                  nitecore-p16-hunting-kit.html
#
# Nitecore P15 430 Lumen LED Flashlight Night Hunting Kit with GM02 Weapon Mount, RSW1 Pressure Switch, NFR60 Red Filter, NFG60 Green Filter - Fits Picatinny Railed Guns
#
# $129.00
#                  nitecore-p15-hunting-kit.html
#
# SOG Tangle Fixed Blade Knife - 3.9-inch Straight Edge, Drop Point - Satin (FX31K) or Hardcased Black (FX32K) - Black Paracord Handle - Hard Nylon Sheath - Clam Pack
#
# $45.03
#                  sog-fx3-opt.html
#
# SOG Zoom Folding Knife - 3.6-inch Straight Edge, Drop Point - Black TiNi (ZM1012) or Satin (ZM1011) Finish - Black Handle or Carbon Fiber (ZM1018) - Boxed
#
# $90.95
#                  sog-zm101-opt.html
#
# Ultimate Survival Technologies ParaKnife FS 4.0 Fixed Blade Knife with Paracord - 4-inch Partially Serrated - Includes Flint Fire Starter - Nylon Sheath - Glo (20-02232-15) or Orange (20-02232-08)
#
# $12.95
#                  ust-20-02232-opt.html
#
# Ultimate Survival Technologies FeatherLite Survival Kit 2.0 - Include Compass, Blanket, Poncho, Whistle, Knife, Light Stick, Flashlight, Mirror, Towel and Matches - Orange (20-723-01)
#
# $19.75
#                  ust-featherlite-survival-kit-2.html
#
# Ultimate Survival Technologies FeatherLite First Aid Kit 3.0 - Includes Bandages and Medicine - Red (80-30-1460)
#
# $15.50
#                  ust-featherlite-first-aid-kit-3.html
#
# Titanium Innovations High Viz Reflective Safety Belt
#
# $2.95
#                  safety-belt.html
#
# SOG Flash II Folding Knife - 3.5-inch Partially Serrated, Drop Point - Black TiNi - Black Handle - Clam Pack (TFSA98-CP)
#
# $48.86
#                  sog-fsa-98-flash2-ser-blk-opt.html
#
# SOG SEAL Ops Fixed Blade Knife - 4.85-inch Straight Edge, Drop Point - Black TiNi - Black Handle - Boxed (M40T-K)
#
# $74.95
#                  sog-m40k-ops-fixed-opt.html
#
# SOG Twitch XL Folding Knife - 3.25-inch Straight Edge, Drop Point - Black TiNi - Black Handle - Clam Pack (TWI-21)
#
# $89.00
#                  sog-twi2-opt.html
#
# SOG Kiku Large Fixed Blade Knife - 5.6-inch Straight Edge, Drop Point - Black TiNi (KU-2012) or Satin (KU-2011) - Linen Micarta Handle - Hard Nylon Sheath - Boxed
#
# $131.93
#                  sog-ku-201-opt.html
#
# SOG Fixed Blade Throwing Knives with Paracord Handle - 4.4-inch Straight Edge - Hardcased Black Finish - Nylon Sheath - 3-Piece Clam Pack (F041TN-CP)
#
# $40.95
#                  sog-f041tn-cp.html
#
# SOG Bladelight Tactical Fixed Blade Knife with Light - 4.5-inch Straight Edge, Drop Point - Hardcased Black Finish - Black Handle - Hard Nylon Sheath - Boxed (BLT22K-CP)
#
# $54.33
#                  sog-blt22k-cp.html
# Olight H05 Active Headlamp - CREE XM-L2 LED - 150 Lumens - Includes 2 x AAAs - Blue, Green, Orange or Purple
#
# $14.95
#                  olight-h05-opt.html
#
# Olight R50 Seeker USB Rechargeable Flashlight - CREE XHP-50 LED - 2500 Lumens - Includes 1 x 26650
#
# $99.95
#                  olight-r50-opt.html
#
# Olight S1A Baton Flashlight with Magnetic Tailcap - CREE XM-L2 LED - Uses 1 x 14500 or 1 x AA (Included)
#
# $39.95
#                  olight-s1a.html
#
# Olight S1A Baton (Limited Edition) Copper Flashlight - CREE XM-L2 LED - 600 Lumens - Uses 1 x 14500 or 1 x AA (Included) - Raw Copper Finish
#
# $54.95
#                  olight-s1a-cu-opt.html
#
# Olight S2A Baton EDC Flashlight - CREE XM-L2 LED - 550 Lumens - Includes 2 x AAs  - Black, Blue, Gray or Yellow
#
# $39.95
#                  olight-s2a-flashlight.html
#
# Olight PL1 II Valkyrie LED Pistol Light - Picatinny and Glock Rails - CREE XP-L CW LED - 450 Lumens - Includes 1 x CR123A
#
# $59.95
#                  olight-valkyrie.html
#
# Bundle: Olight X7 Marauder Search Light Kit - 3 x CREE XHP70 LEDs - 9000 Lumens - Includes Charger and 4 x Olight HDC 3500mAh 18650 Batteries
#
# $219.95
#                  olight-x7-kit.html
#
# Olight X7 Marauder Search Light - 3 x CREE XHP70 LEDs - 9000 Lumens - Uses 4 x 18650
#
# $149.95
#                  olight-x7.html
#
# Nitecore HC33 High Performance LED Headlamp - CREE XHP35 - 1800 Lumens - Uses 1 x 18650 or 2 x CR123As - Now Available with a Battery and a Charger
#
# $64.95
#                  nitecore-hc33-headlamp.html
#
# Fenix TK32 (2016) Tactical Flashlight - CREE XP-L HI V3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123As
#
# $94.95
#                  fenix-tk32-2016.html
#
# Fenix PD35 TAC Portable High Intensity Tactical Flashlight - CREE XP-L V5 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A
#
# $71.95
#                  fenix-pd35-tac.html
#
# Fenix PD32 (2016) Portable High Intensity Flashlight - CREE XP-L HI LED - 900 Lumens - Uses 1 x 18650 or 2 x CR123A
#
# $61.95
#                  fenix-pd32-g3.html
#
# Fenix TK09 (2016) Tactical Flashlight - CREE XP-L HI LED - 900 Lumens - Uses 1 x 18650 or 2 x CR123As
#
# $64.95
#                  fenix-tk09-xpl.html
#
# Fenix TK15UE Ultimate Edition Tactical Flashlight - CREE XP-L HI V3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123As - Black or Grey
#
# $74.95
#                  fenix-tk15ue-opt.html
#
# Fenix TK25 IR LED Flashlight - CREE XP-G2 S3 - 850nm IR - 1000 lumens - Uses 1x 18650 or 2x CR123A
#
# $99.95
#                  fenix-tk25-ir-infrared-led-flashlight.html
#
# Fenix TK16 Tactical Flashlight - CREE XM L2 U2 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123As
#
# $79.95
#                  fenix-tk16-xml2-u2.html
#
# Nitecore TM38-LITE Tiny Monster Lite Rechargeable Flashlight - CREE XHP35 HI D4 - 1800 Lumens - Uses 4 x 18650 - Now Available with Batteries
#
# $359.95
#                  nitecore-tm38-lite-tactical-led-flashlight.html
#
# Nitecore SmartRing Tactical SRT9 LED Flashlight - CREE XHP50 White LED - Red, Blue, Green, and UV LEDs - 2150 Lumens - Uses 2 x 18650 or 4 x CR123A - Now Available with Batteries & a Charger
#
# $119.95
#                  nitecore-srt9-tactical-flashlight.html
#
# Nitecore Concept 1 Everyday Carry Flashlight - CREE XHP35 HD E2 LED - 1800 Lumens - Uses 1 x 18650 or 2 x CR123As - Now Available with Batteries & a Charger
#
# $64.95
#                  nitecore-concept-1-led-flashlight.html
#
# iPower AA Charger Kit - Includes 8 iPower 2600mWh 1.5V Protected Lithium Polymer (LiCoO2) Button Top Batteries and 1 iPower AA8 8-Bay Fast Smart Charger
#
# $125.95
#                  ipower-8aa-batteries-and-charger-kit.html
#
# BUNDLE: Olight S2R Baton Rechargeable Flashlight Kit - CREE XM-L2 LED - 1020 Lumens - Uses 2 x CR123As or 1 x 18650 (2x Included)
#
# $90.04
#                  olight-s2r-flashlight-bundle.html
#
# BUNDLE: Olight S30R Baton III Rechargeable Flashlight Kit - CREE XM-L2 LED - 1050 Lumens - Uses 1 x 18650 (2x Included)
#
# $97.05
#                  olight-s30r-iii-flashlight-bundle.html
#
# BUNDLE: Olight M3XS-UT Ultra-Thrower Javelot Search Light Kit - CREE XP-L Dedomed LED - 1200 Lumens- Uses 3 x CR123As or 2 x 18650s (Included)
#
# $185.90
#                  olight-m3xs-ut-flashlight-bundle.html
#
# BUNDLE: Olight R20 Javelot USB Rechargeable Flashlight Kit - CREE XP-L LED - 900 Lumens - Uses 1 x 18650 (2x Included)
#
# $68.95
#                  olight-r20-flashlight-bundle.html
#
# BUNDLE: Olight M1X Striker Flashlight Kit - CREE XM-L2 CW LED - 1000 Lumens - Uses 2 x CR123As or 1 x 18650 (Included)
#
# $68.95
#                  bdl-olight-m1x-striker-xml2.html
#
# BUNDLE: Olight M2X-UT Ultra-Thrower Javelot Search Light Kit - CREE XM-L2 LED - 1020 Lumens - Uses 2 x CR123As or 1x 18650 (Included)
#
# $118.95
#                  bdl-olight-m2x-ut.html
#
# Nitecore Chameleon CI6 Infrared Flashlight Combo - CREE XP-G2 R5 and CREE XP-E R2 LED - 440 Lumens - With Battery and Charger
#
# $94.93
#                  bdl-nitecore-ci6-xpg2-smo-rch.html
#
# Nitecore Chameleon CR6 Red Tactical Flashlight Combo - CREE XM-L2 and CREE XP-G2 R5 LED - 440 Lumens - With Battery and Charger
#
# $84.93
#                  bdl-nitecore-cr6-xpg2-smo-rch.html
#
# Nitecore HC30 LED Headlamp Combo - CREE XM-L2 U2 LED (Cool or Neutral White) - 1000 Lumens - With Battery and Charger
#
# $65.43
#                  bdl-nitecore-hc30-rch.html
#
# BUNDLE: Nitecore MH12 Tactical Flashlight Combo - CREE XM-L2 LED - 1000 Lumens - with Battery and Charger
#
# $94.93
#                  bdl-nitecore-mh12-xm-l2-rch.html
#
# Nitecore MH1A Rechargeable Flashlight Combo - CREE XM-L U2 LED - 550 Lumens - With Battery and Charger
#
# $82.43
#                  bdl-nitecore-mh1a-smo-rch.html
#
# BUNDLE: Nitecore MH27 Rechargeable Flashlight Combo - CREE XP-L HI V3 LED - 1000 Lumens - with Battery and Charger
#
# $104.93
#                  bdl-nitecore-mh27-rch.html
#
# Nitecore MT10C Tactical Flashlight Combo - CREE XM-L2 U2 LED - 920 Lumens - With Battery and Charger
#
# $74.90
#                  bdl-nitecore-mt10c-rch.html
#
# Nitecore MT20C Tactical Flashlight Combo - CREE XP-G2 R5 LED - 460 Lumens - With Battery and Charger
#
# $76.93
#                  bdl-nitecore-mt20c-xpg2-r5-rch.html
#
# BUNDLE: Nitecore MT40GT Search Light Flashlight Combo - CREE XP-L-HI V3 LED - 1000 Lumens -  with Battery and Charger
#
# $101.43
#                  bdl-nitecore-mt40gt-rch.html
#
# Nitecore P20UV Ultraviolet Flashlight Combo - CREE XM-L2 LED - 800 Lumens - With Battery and Charger
#
# $90.93
#                  bdl-nitecore-p20uv-rch.html
#
# Nitecore P20 Tactical Flashlight Combo - CREE XM-L2 LED - 800 Lumens - With Battery and Charger
#
# $79.93
#                  bdl-nitecore-p20-xml2-rch.html
#
# Nitecore TM06 Tiny Monster Flashlight Combo -  4 x CREE XM-L2 U2 LED - 3800 Lumens - With Batteries and Charger -
#
# $239.20
#                  bdl-nitecore-tm06-rch.html
#
# BUNDLE: Nitecore TM15 Tiny Monster Flashlight Combo - 3 x CREE XM-L2 LED - 2650 Lumens  - with Battery and Charger
#
# $338.25
#                  bdl-nitecore-tm15-xml2-rch.html
#
# Nitecore Chameleon CU6 Ultraviolet Flashlight Combo - CREE XP-G2 R5 and CREE XP-E R2 - 440 Lumens - LED With Battery and Charger
#
# $124.93
#                  bdl-nitecore-cu6-xpg2-smo-rch.html
#
# Nitecore EC20 Tactical Flashlight Combo - CREE XM-L2 T6 LED - 960 Lumens - With Battery and Charger
#
# $59.93
#                  bdl-nitecore-ec20-rch.html
#
# Nitecore EC4 Flashlight Combo - CREE XM-L2 U2 LED - 1000 Lumens - With Battery and Charger
#
# $86.43
#                  bdl-nitecore-ec4-xm-l2-rch.html
#
# Nitecore EF1 Explosion-Proof Flashlight Combo - CREE XM-L2 U3 LED - 830 Lumens - With Battery and Charger
#
# $163.98
#                  bdl-nitecore-ef1-rch.html
#
# Nitecore MT10A Tactical Flashlight Combo - CREE XM-L2 U2 LED - 920 Lumens - With Battery and Charger
#
# $69.43
#                  bdl-nitecore-mt10a-rch.html
#
# BUNDLE: Nitecore P15 Tactical Flashlight Combo - CREE XP-G2 LED - 430 Lumens - with Battery and Charger
#
# $74.93
#                  bdl-nitecore-p15-xpg2-smo-rch.html
#
# BUNDLE: Nitecore TM16 Tiny Monster Flashlight Combo - CREE XM-L2 U2 LED - 4000 Lumens - with Batteries and Charger
#
# $239.20
#                  bdl-nitecore-tm16-rch.html
#
# Nitecore Chameleon CB6 Blue Tactical Flashlight Combo - CREE XM-L2 and CREE XP-G2 R5 LED - 440 Lumens -  With Battery and Charger
#
# $84.93
#                  bdl-nitecore-cb6-xpg2-smo-rch.html
#
# Nitecore P36 Tactical Flashlight Combo - CREE MT-G2 LED - 2000 Lumens - With Battery and Charger
#
# $151.43
#                  bdl-nitecore-p36-mt-g2-rch.html
#
# Nitecore P12 2015 Edition Flashlight Combo - CREE XM-L2 (U2) LED - 1000 Lumens - With Battery and Charger
#
# $74.93
#                  bdl-nitecore-p12-smo-xml2-rch.html
#
# Nitecore Chameleon CG6 Green Tactical Flashlight Combo - CREE XM-L2 and CREE XP-G2 R5 - 440 Lumens - With Battery and Charger
#
# $84.93
#                  bdl-nitecore-cg6-xpg2-smo-rch.html
#
# Nitecore EC11 EDC Flashlight Combo - CREE XM-L2 (U2) LED - 900 Lumens - With Battery and Charger
#
# $72.90
#                  bdl-nitecore-ec11-rch.html
#
# Nitecore EA11 EDC Flashlight Combo - CREE XM-L2 (U2) LED - 900 Lumens - With Battery and Charger
#
# $67.43
#                  bdl-nitecore-ea11-rch.html
#
# Nitecore EC4S Search Light Combo - CREE XPH50 LED - 2150 Lumens - With Battery and Charger
#
# $119.43
#                  bdl-nitecore-ec4s-rch.html
#
# Nitecore MH20 Rechargeable Flashlight Combo - CREE XM-L2 (U2) LED -1000 Lumens - With Battery and Charger
#
# $94.93
#                  bdl-nitecore-mh20-rch.html
#
# BUNDLE: Nitecore P12GT Tactical Flashlight Combo - CREE XP-L HI V3 LED - 1000 Lumens - with Battery and Charger
#
# $86.93
#                  bdl-nitecore-p12gt-rch.html
#
# BUNDLE: Nitecore TM26 Tiny Monster Quad Ray Flashlight Combo - 4 x CREE XM-L2 LED - 4000 Lumens - with Batteries and Charger
#
# $429.25
#                  bdl-nitecore-tm26-xml2-rch.html
# Nitecore Explorer EA45S Flashlight - CREE XP-L HI V3 LED - 1000 Lumens - Uses 4 x AAs
#
# $59.96
#                  nitecore-ea45s.html
#
# JETBeam DDA20 Digital Display Flashlight - CREE XP-G2 R5 LED - 285 Lumens - Uses 2 x AAs
#
# $44.50
#                  jetbeam-dda20.html
#
# JETBeam DDC10 Digital Display Flashlight - CREE XP-G2 R5 LED - 285 Lumens - Uses 1 x CR123A
#
# $42.50
#                  jetbeam-ddc10.html
#
# JETBeam DDA10 Digital Display Flashlight - CREE XP-G2 R5 LED - 160 Lumens - Uses 1 x AA
#
# $39.50
#                  jetbeam-dda10.html
#
# JETBeam DDR30-GT Rechargeable Digital Display Flashlight - CREE XHP70 LED - 3680 Lumens - Uses 4 x 18650s
#
# $129.50
#                  jetbeam-ddr30-gt-flashlight.html
#
# JETBeam DDR26 USB Rechargeable Digital Display Flashlight - CREE XP-L LED - 1100 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $98.00
#                  jetbeam-ddr26-xp-l.html
#
# Titanium Innovations 8-In-1 Sony Type Camcorder Battery Charger - AC 100-240V AC + DC Adapters
#
# $3.95
#                  titanium-chrg-8-in-1-sony.html
#
# Golden Gadgets 68 UV LED Flashlight - Runs on 4 x AAA Batteries - Black or Silver
#
# $49.98
#                  gds-f-68led-uv-flashlight-opt.html
#
# Renata 386 45mAh 1.55V Silver Oxide Coin Cell Battery (386-MP) - Tear Strip
#
# $2.85
#                  renata-386-mp.html
#
# Nitecore Tiny Monster TM15 Flashlight - 3 x CREE XM-L2 LEDs - 2650 Lumens - Uses 4 x 18650s or 8 x CR123As
#
# $224.25
#                  nitecore-tm15-xml2.html
#
# Nite Ize Clip Case Sideways Leather Holster - 4.5" x W 2.5" x D 0.9" - Medium - Espresso
#
# $19.99
#                  niteize-sideways.html
#
# Fenix Red Diffuser Tip - 1.38" x 4.69" - Large for TK Series Lights (AD102-R)
#
# $3.20
#                  fenix-ad102-r.html
#
# Fenix AOD-M Diffuser Tip for Select TK-Series - E-Series - and RC-Series Flashlights
#
# $4.50
#                  fenix-aod-m.html
#
# Fenix TK51 Dual-Output Tactical Flashlight - 2 x CREE XM-L2 U2 LEDs - 1800 Lumens - Uses 3 x 18650s
#
# $127.96
#                  fenix-tk51-xml2.html
#
# Fenix TK76 Tactical Flashlight - 3 x CREE XM-L2 U2 LEDs - 2800 Lumens - Uses 4 x 18650s or 8 x CR123As
#
# $239.96
#                  fenix-tk76-xml2.html
#
# Fenix UC35 USB Rechargeable Flashlight - CREE XM-L2 U2 LED - 960 Lumens - Uses 2 x CR123A or 1 x 18650 (Included)
#
# $89.95
#                  fenix-uc35-xml2-u2.html
#
# Fenix SD10 Diving Flashlight with Motion Control Technology - CREE XM-L2 T6 LED - Neutral White - 930 Lumens - Uses 2 x CR123A or 1 x 18650
#
# $79.96
#                  fenix-sd10-xml2.html
#
# Fenix LD50 Professional Outdoor Dual-Output Flashlight - 2 x CREE XM-L2 U2 LEDs -  1800 Lumens - Uses 2 x CR123As or 1 x 18650
#
# $119.95
#                  fenix-ld50-xml2-u2.html
#
# Fenix Flashlights Filters (Blue & Red) for TK Series: TK10, TK11 & TK20
#
# $4.80
#                  fenix-tk-red.html
#
# Fenix Headband Fits 18-22mm Diameter Lights (FX-HB)
#
# $19.95
#                  fenix-headband.html
#
# Energizer Max E91-BP-6 AA 1.5V Alkaline Button Top Batteries - 6 Piece Retail Card
#
# $6.95
#                  energizer-e91bpf-6.html
#
# Spotlight Rescue 12V LED Rechargeable Flashlight - Jet Black (SPOT-8809)
#
# $38.97
#                  spotlight-8809.html
#
# Nite Ize Action Armband for Smartphones - Includes S-Biner and Curvyman Cord Supervisor - Fits iPhone 6S and Samsung Galaxy S7 - Black (NIPB2-01-R8)
#
# $23.99
#                  niteize-nipb2-01-r8.html
#
# Fenix HP40F High Performance Fishing Headlamp - CREE XP-G2 R5  / XP-E2 M3 LED - 450 Lumens - 3000 mW Blue Light - Uses 4 x CR123As or 2 x 18650s
#
# $67.46
#                  fenix-hp40f-xpe2.html
#
# Fenix HP01 High Performance Headlamp - CREE XP-G R5 LED and Nichia Red LED - 210 Lumens - Uses 2 x AAs - Orange
#
# $37.46
#                  fenix-hp01-xpgr5-orange.html
#
# Niteye EYE30 Black Flashlight - 3 x CREE XM-L U2 LED - 2000 Lumens - Uses 4 x 18650
#
# $289.00
#                  niteye-eye30-xml2-black.html
#
# Underwater Kinetics Remora Titanium Fixed Blade Knife - 2.9-inch Serrated, Blunt Tip - Black with Yellow Accents or Solid Black Handle
#
# $78.94
#                  uk-remora-ti-bt-opt.html
#
# 12V Spotlight Fender Friend from Titanium Innovations
#
# $9.95
#                  titanium-spotlight-fender-friend.html
#
# Sunwayman M10R Flashlight with Magnetic Control - CREE XM-L T6 LED - 210 Lumen  - Uses 1 x CR123A or 1 x 16340
#
# $71.00
#                  sunwayman-m10r-xml.html
#
# Energizer Max E93-BP-4 C-cell Alkaline Button Top Battery - 4 Piece Retail Card
#
# $6.95
#                  energizer-e93bp-4.html
#
# Fenix White Diffuser Tip for TK Series LED Flashlights
#
# $2.80
#                  fenix-wdt-tk.html
#
# Niteye 12V DC Car Charger for Eye30 and Eye40 Searchlights
#
# $4.75
#                  niteye-eye30-eye40-car-charger.html
#
# Niteye EYE30 Black Flashlight w/ DC Car Charger - 3 x CREE XM-L U2 LED - 2000 Lumens - Uses 4 x 18650 - Black
#
# $299.00
#                  niteye-eye30-xml2-black-kit.html
#
# Olight M30 Blue Filter For M30 Flashlights
#
# $5.50
#                  olight-m30-blue-filter.html
#
# Olight Red Filter for M30 Series LED Flashlights
#
# $5.50
#                  olight-m30-red-filter.html
#
# Niteye EYE30 Grip Carry Handle - Black
#
# $25.00
#                  niteye-eye30-handle.html
#
# Underwater Kinetics UK2AAA eLED Mini Pocket Light - 7 Lumens - Uses 2 x AAAs - Black or Safety Yellow
#
# $20.00
#                  uk-mini-pktl-led-opt.html
#
# AE Light MK2 Flashlight - CREE XP-G R5 LED - 230 Lumens - Uses 2 x CR123A or 1 x 18650
#
# $100.00
#                  aelight-mk2-blister-r5.html
#
# LumaPower Signature Tactical VX LED Flashlight, Luminus SST-50 LED,  500 Lumens 2XCR123A , 1X18650
#
# $129.95
#                  lumapower-signature-vx-500.html
#
# Titanium Innovations Lense & Diffuser Kit for N30 & L35 Spotlights
#
# $39.95
#                  l35-lkit-a.html
#
# PowerTac Thunderbolt Rechargeable LED Flashlight - 1150 Lumens - CREE XM-L (U2) LED - Includes Battery Pack
#
# $213.00
#                  powertac-thunderbolt.html
#
# Powertac E8 Rechargeable Flashlight - CREE XP-G2  - 340 Lumens - Uses 1 x 18650
#
# $49.95
#                  powertac-e8.html
#
# Energy+ BR-ACF2P 1800mAh 6V Lithium (LiMnO2) Battery Pack - Replacement for GE Fanuc and Cutler Hammer - Heat Sealed Bag
#
# $28.01
#                  fc-br-acf2p.html
#
# Energizer Max 522-BP 9V Alkaline Battery with Snap Connector - 1 Piece Retail Card
#
# $3.95
#                  energizer-522bp.html
#
# Glo-Toob Infrared Light Stick - Uses 23A Alkaline Batteries
#
# $32.87
#                  glo-toob-ir-alkaline-opt.html
#
# Energizer MILHL11L - Military Tactical Helmet Light - Uses 1 x AA Batteries
#
# $98.03
#                  energizer-milhl11l.html
#
# Energizer Max E91-BP-2 AA 1.5V Alkaline Button Top Batteries - 2 Piece Retail Card
#
# $2.45
#                  energizer-e91bp-2.html
#
# Nite Ize Backbone Case - Size #10 - Small - Mossy Oak (NBB-03-10MO)
#
# $12.09
#                  nbb-03-10.html
#
# Sillites Electric Window Candle - 7.5" or 9" - Antique Bronze, Brushed Nickel, Matte Black or Polished Brass
#
# $55.95
#                  sillites.html
#
# Wiley X WX Talon Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (CHTAL1 CHTAL1RX CHTAL2 CHTAL2RX)
#
# $85.50
#                  wileyx-wx-talon-opt.html
#
# Wiley X P-17 Sunglasses with High Velocity Protection Active Series in Various Color Schemes (P-17NP P-17M P-17 P-17GM)
#
# $71.95
#                  wileyx-p-17-opt.html
#
# Klarus RS1A Rechargeable LED Flashlight with CREE XP-G2 LED up to 210 Lumens - Uses 1 x NiMH AA
#
# $63.96
#                  klarus-rs1a-xp-g2.html
#
# Niteye 12V AC Power Adapter for the EYE25, EYE30, and EYE40 LED Flashlights
#
# $14.25
#                  niteye-eye30-ac-charger.html
#
# Energizer Max E92-BP-2 AAA 1.5V Alkaline Button Top Batteries - 2 Piece Retail Card
#
# $2.50
#                  energizer-e92bp-2.html
#
# Ultimate Survival Technologies B.A.S.E. Bug Tent For One - 21 x 72 x 34-inch Mesh Camping Shelter (20-5000-01)
#
# $19.75
#                  ust-20-5000-01.html
#
# Sunforce 60 Watt Crystalline Solar Panel (37015)
#
# $424.96
#                  sunforce-37015.html
#
# Sunforce Solar Dock Light (84507)
#
# $23.96
#                  sunforce-84507.html
#
# JETBeam RM-46 Weapon Rail Mount for Raptor RRT-3 Flashlight - Fits Picatinny Rails - Black
#
# $66.00
#                  jetbeam-3-rail-mount.html
#
# ZTS Soft Case / Carrying pouch For MBT-LA Testers
#
# $6.76
#                  sc-mbtla.html
#
# Nite Ize KnotBone Knot Replacement - Fits 9mm Cords - Black (KB9-02-01)
#
# $5.95
#                  niteize-kb9-02-01.html
#
# LumaPower Signature LX Power Pack LED Flashlight with CREE XM-L LED Cool White - Uses 2 x CR123A or 1 x 18650
#
# $114.95
#                  lumapower-signature-lx-pp-xml-cw.html
#
# Fenix AR101 Remote Pressure Switch for TK Series LED Flashlights - Works with TK10 - TK11-Q5 - TK11-R2 and TK20
#
# $8.37
#                  fenix-t-pressure.html
#
# Fenix AB02 Flashlight Belt Clip
#
# $8.50
#                  fenix-ab02.html
#
# Niteye 12V DC Power Adapter for the EYE25, EYE30, and EYE40 LED Flashlights
#
# $4.05
#                  niteye-eye30-dc-charger.html
#
# SOG PowerAssist EOD Multi-Tool - Includes 10 Tools - Satin (S67) - Leather  or Nylon Sheath
#
# $73.25
#                  sog-s67-powerassist-eod-opt.html
#
# Nite Ize Rugged Case for Blackberry Cell Phone (BHC2-03-01)
#
# $11.19
#                  bhc2-03-01.html
#
# Nite Ize Tone Nite Club Cell Phone Holster with Magnetic Closure - Embroidered Sage (NNC-03-MAG28)
#
# $15.00
#                  nnc-03-mag28.html
#
# Nite Ize Tone Nite Club Cell Phone Holster with Magnetic Closure - Embroidered Black (NNC-03-MAG01)
#
# $15.00
#                  nnc-03-mag01.html
#
# Stallion Leather Holder for Inova T4 and Polystinger Flashlights FPSH
#
# $32.55
#                  stlehoforint4.html
#
# Sunforce Solar Flashing Alarm System (86319)
#
# $110.46
#                  sunforce-86319.html
#
# SOG Tech Bowie Fixed Black Knife -  6.4-inch Straight Edge, Clip Point - Black TiNi - Black Handle - Boxed (S10B-K)
#
# $116.51
#                  sog-s10-k-tech-bowie-fix-opt.html
#
# SOG SEAL Team Fixed Blade Knife - 7-inch Partially Serrated, Clip Point - Black Powder Coated - Black Handle - Kydex or Nylon Sheath - Boxed (S37)
#
# $90.33
#                  sog-s37-seal-team-fix-opt.html
#
# Underwater Kinetics UK3AA eLED CPO-AT Flashlight with Tail Switch - 8 Lumens - Class I Div 1 - Uses 3 x AAs - Black or Safety Yellow
#
# $34.39
#                  uk-cpo-at-tl-swtch-opt.html
#
# ZTS LSP-MBTLA2 Plier-Type Lead Set - Jaw Opening 1.125"
#
# $59.95
#                  zts-lsc-mbt-la2.html
#
# Fenix Flashlights FX-RD Red Diffuser Wand  fits L and P series Fenix flashlights
#
# $1.65
#                  fenix-fx-rd.html
#
# Padded Pouch for Mini-MBT Tester (SC-MINI)
#
# $3.36
#                  sc-mini.html
#
# AE Light MK2 Flashlight Kit w/ Charger - CREE XP-G R5 LED - 230 Lumens - Uses 2 x CR123A or 1 x 18650 (Included)
#
# $120.00
#                  aelight-mk2-kit-r5.html
#
# SpotLight Shifter 3.0 LED Flashlight - 200 Lumens - Runs on 3x AAA battery (Included) - Jet Black
#
# $29.97
#                  spotlight-6309.html
#
# Smith & Wesson M&P; 7 Tactical LED Flashlight - 275 Lumens - 1007CREE - Uses 3 x AAA
#
# $43.96
#                  smith-wesson-mp7.html
#
# Wagan 2295-6 SmartAC 210W Power Inverter With USB Port
#
# $30.85
#                  wagan-2295-6.html
#
# JETBeam DDA10 Digital Display Flashlight - CREE XP-G2 R5 LED - 160 Lumens - Uses 1 x AA
#
# $39.50
#                  jetbeam-dda10.html
#
# Coleman 58032 18 Watt Solar Battery Charger
#
# $76.46
#                  coleman-58032.html
#
# AE Light Top Gun MK1 LED Tactical Flashlight - 180 Lumens - Includes Li-ion Battery Pack
#
# $200.00
#                  aelight-top-gun-mk-1.html
#
# Energizer ELCR123A-BP 1500mAh 3V Lithium Primary (LiMNO2) Button Top Photo Battery - 1  Piece Retail Card
#
# $3.95
#                  energizer-el123apbp.html
# SureFire HL1-C Tactical Helmet Light with 3 x White, 2 x Red and 1 x Infrared IFF LEDs - 19.2 Lumens - Includes 1 x CR123A  - Desert Tan (HL1-C-TN)
#
# $169.00
#                  hl1-c-tn.html
#
# AE Light W30 LifeLight Dive Light - CREE Q5 LED - 270 Lumens - Uses 3 x AAs - Class I Div 1 (AE-W30)
#
# $150.00
#                  ae-w30.html
#
# MAXPEDITION JUMBO Versipack 0412
#
# $97.95
#                  majuve04.html
#
# Streamlight 4AA ProPolymer Lux Div 2 Safety-Rated Polymer LED Flashlight - C4 LED - 100 Lumens - Class I Div 2 - Includes 4 x AAs - Yellow or Black
#
# $32.95
#                  stpr4aaluled.html
#
# Stallion Leather Holster for Inova T5 Flashlight T5
#
# $41.99
#                  stlehoforint5.html
#
# Coleman 68032 30 Amp Digital Charge Controller
#
# $71.36
#                  coleman-68032.html
#
# Glo-Toob IR Lithium Infrared Light Stick - Runs on 1 x CR123A (Included)
#
# $39.91
#                  glo-toob-ir-lithium-opt.html
#
# Wagan 2003-5 Slim Line 400W/1000W Inverter 5V2.1A USB
#
# $44.90
#                  wagan-2003-5.html
#
# Wagan 2561 Exec Duo-Solar iPhone Charger/Leather Case
#
# $54.95
#                  wagan-2561.html
#
# Titanium Innovations Smart Peak AC Delta Peak Wall Charger - 6 to 7 Cells - NiMH and NiCd Battery Packs
#
# $12.95
#                  titanium-ch-485.html
#
# Streamlight TL-2 Tactical Flashlight - C4 LED - 120 Lumens - Includes 2 x CR123As (88305)
#
# $65.95
#                  streamlight-88305.html
#
# BatteryJunction.com Cotton T-Shirt
#
# $6.80
#                  battjnc-t-shirt-opt.html
#
# Wagan  2510 - 30A Solar Charge Controller
#
# $54.90
#                  wagan-2510.html
#
# AELight - XENIDE Power Cord Adapter for constant in-vehicle use
#
# $28.05
#                  aex-car-charger.html
#
# Pelican 7052OR Traffic Wand - 1.65" x 6.50" - Orange (7050-980-150)
#
# $7.23
#                  pelican-7050-980-150.html
#
# Streamlight SL-20X Rechargeable Flashlight with 120V AC Charger - LED and Halogen Bulbs - 200 Lumens - Includes NiCd Battery Pack (20201)
#
# $122.95
#                  streamlight-20201.html
#
# Wagan Solo - Solar iPhone Charger Case (2559) - Fits iPhone 3 & 3GS
#
# $39.95
#                  wagan-2559.html
#
# Tenergy 5000mAh 8.4V Flat Nickel Metal Hydride  (NiMH) Battery Pack - Traxxas Connectors
#
# $41.95
#                  tenergy-84-5000-nimh-pack.html
#
# Streamlight Flashlight Battery: 6V 3000mAh NiMH Battery Stick for the Super Stinger, Ultra Stinger, SL-20L, 77175 and 9926J
#
# $24.95
#                  powerizer-nimh-fb-5hsc3000ia.html
#
# Energy+ BR-CCF1TH 5000mAh 3V Lithium (LiMnO2) Battery Pack for GE Fanuc - Heat Sealed Bag
#
# $14.92
#                  fc-br-ccf1th.html
#
# Streamlight Tactical Strion 74202 Rechargeable LED Flashlight with Weapon Mount, 120V AC/DC Charger and 1 x Holder - Fits Picatinny Railed Long Guns - 85 Lumens - Includes Li-ion Battery Pack
#
# $146.95
#                  streamlight-74202.html
#
# Glo-Toob Flash Cap - 4 Color Options
#
# $29.71
#                  glo-toob-flash-cap-opt.html
#
# Powerizer Lead Acid Smart Charger (10 A) for 12V Lead Acid Battery for Worldwide Use
#
# $41.95
#                  powerizer-ch-la12v10a.html
#
# Sielo (previously known as TerraLUX) Line Voltage 6 Inch Linear LED Engine for 120V AC Phase Dimming with 3000k Color Temperature (TLM-L06A-A063012R)
#
# $63.10
#                  terralux-tlm-l06a-a063012r.html
#
# Sielo (previously known as TerraLUX) Line Voltage 6 Inch Linear LED Engine for 120V AC Phase Dimming with 2700k Color Temperature (TLM-L06A-A062712R)
#
# $63.10
#                  terralux-tlm-l06a-a062712r.html
#
# Sielo (previously known as TerraLUX) Line Voltage 4 Inch Linear LED Engine for 120V AC Phase Dimming with 4000k Color Temperature (TLM-L04A-A044012R)
#
# $54.76
#                  terralux-tlm-l04a-a044012r.html
#
# Sielo (previously known as TerraLUX) Line Voltage 4 Inch Linear LED Engine for 120V AC Phase Dimming with 3000k Color Temperature (TLM-L04A-A043012R)
#
# $54.76
#                  terralux-tlm-l04a-a043012r.html
#
# Sielo (previously known as TerraLUX) Line Voltage 8 Inch Linear LED Engine for 120V AC Phase Dimming with 3500k Color Temperature (TLM-L08A-A083512R)
#
# $70.24
#                  terralux-tlm-l08a-a083512r.html
#
# Sielo (previously known as TerraLUX) 180 Degree Diffuser for Linear LED Module - 4, 6 or 8 Inch
#
# $1.20
#                  terralux-tlma-2020000-opt.html
#
# AE Light Xenide 20W HID Flashlight Searchlight 1200 lumens! AEX20
#
# $483.00
#                  aex20.html
#
# Fenix Battery Storage Cap - Works with L1D - L2D - L1T V2 - L2T V2 - P2D - and P3D
#
# $0.80
#                  fenix-storage-cap.html
#
# Olight RM2R Tactical Remote Pressure Switch for the Olight M2R Warrior
#
# $15.95
#                  olight-rm2r-tactical-remote-pressure-switch.html
#
# Olight S1 MINI Baton EDC Flashlight - CREE XM-L2 CW LED - 600 Lumens - Includes 1 x 16340 RCR123A
#
# $49.95
#                  olight-s1-mini-baton-edc-flashlight.html
#
# Olight S1 MINI HCRI Baton High CRI Flashlight - CREE XP-G3 90 CRI - 450 Lumens - Includes 1 x 16340 RCR123A
#
# $49.95
#                  olight-s1-mini-baton-high-cri-flashlight.html
#
# Olight S10R Baton III Flashlight - LUMINUS SST-40 LED - 600 Lumens - USB Rechargeable - Includes 1 x RCR123A
#
# $59.95
#                  olight-s10r-iii.html
#
# Olight S1R Turbo Baton Rechargeable LED Flashlight - CREE XM-L2 LED - 900 Lumens - 2nd Edition - Uses 1 x 16340 (Included) or 1 x CR123A
#
# $64.95
#                  olight-s1r-turbo.html
#
# Olight Holster for the M2R Warrior Flashlight - Desert Tan
#
# $14.95
#                  olight-m2r-flashlight-holster.html
#
# Olight M2R Warrior Rechargeable Pocket-Friendly Tactical Flashlight - CREE XHP35 HD LED - Cool White or Neutral White - 1500 Lumens - Uses 1 x 18650 (Included) or 2 x CR123As
#
# $99.95
#                  olight-m2r-tactical-led-flashlight.html
#
# Olight PL-MINI Valkyrie Rechargeable Pistol Light - CREE XP-L HI CW LED - 400 Lumens - Includes Battery Pack
#
# $79.95
#                  olight-pl-mini-led-pistol-light.html
#
# Olight X7R Marauder Rechargeable LED Search Light - 3 x CREE XHP70 LEDs - 12000 Lumens - Includes Built-In Li-Ion Battery Pack
#
# $279.95
#                  olight-x7r-rechargeable-led-search-light.html
#
# Olight ORB-186C30 18650 3000mAh 3.6V Protected Lithium Ion (Li-ion) Button Top Battery for the H2R
#
# $18.99
#                  olight-h2r-18650-battery.html
#
# Olight H2R Nova CW Rechargeable LED Headlamp - CREE XHP50 LED - 2300 Lumens (Cool White) or 2000 Lumens (Neutral White) - Includes 1 x 18650
#
# $89.95
#                  olight-h2r-nova-led-headlamp.html
#
# Olight PL-2 Valkyrie LED Pistol Light - Picatinny and Glock Rails - CREE XHP35 HI CW LED - 1200 Lumens - Includes 2 x CR123As
#
# $99.95
#                  olight-pl-2-valkyrie-weapon-light.html
#
# Olight ORB-186S35 HDC 18650 3500mAh 3.6V Protected High-Drain 10A Lithium Ion (Li-ion) Button Top Batteries for the X7 - 4 Pack Retail Card
#
# $75.96
#                  olight-18650-hdc-3500mah.html
#
# Olight LG ORB-186L34 18650 3400mAh 3.6V Protected Lithium Ion (Li-Ion) Button Top Battery - Plastic Box or Retail Card
#
# $15.99
#                  olight-lg-18650-3400mah-battery.html
#
# Olight ORB-186P32 18650 3200mAh 3.6V Protected Lithium Ion (Li-ion) Button Top Battery - Plastic Box or Retail Card
#
# $14.99
#                  olight-18650-3200mah-battery.html
#
# BUNDLE: Olight S2R Baton Rechargeable Flashlight Kit - CREE XM-L2 LED - 1020 Lumens - Uses 2 x CR123As or 1 x 18650 (2x Included)
#
# $90.04
#                  olight-s2r-flashlight-bundle.html
#
# BUNDLE: Olight S30R Baton III Rechargeable Flashlight Kit - CREE XM-L2 LED - 1050 Lumens - Uses 1 x 18650 (2x Included)
#
# $97.05
#                  olight-s30r-iii-flashlight-bundle.html
#
# BUNDLE: Olight S2R Baton Rechargeable Flashlight Kit - CREE XM-L2 LED - 1020 Lumens - Uses 2 x CR123As or 1 x 18650 (2x Included)
#
# $90.04
#                  olight-s2r-flashlight-bundle.html
#
# BUNDLE: Olight S30R Baton III Rechargeable Flashlight Kit - CREE XM-L2 LED - 1050 Lumens - Uses 1 x 18650 (2x Included)
#
# $97.05
#                  olight-s30r-iii-flashlight-bundle.html
#
# BUNDLE: Olight M3XS-UT Ultra-Thrower Javelot Search Light Kit - CREE XP-L Dedomed LED - 1200 Lumens- Uses 3 x CR123As or 2 x 18650s (Included)
#
# $185.90
#                  olight-m3xs-ut-flashlight-bundle.html
#
# BUNDLE: Olight R20 Javelot USB Rechargeable Flashlight Kit - CREE XP-L LED - 900 Lumens - Uses 1 x 18650 (2x Included)
#
# $68.95
#                  olight-r20-flashlight-bundle.html
#
# BUNDLE: Olight M1X Striker Flashlight Kit - CREE XM-L2 CW LED - 1000 Lumens - Uses 2 x CR123As or 1 x 18650 (Included)
#
# $68.95
#                  bdl-olight-m1x-striker-xml2.html
#
# BUNDLE: Olight M2X-UT Ultra-Thrower Javelot Search Light Kit - CREE XM-L2 LED - 1020 Lumens - Uses 2 x CR123As or 1x 18650 (Included)
#
# $118.95
#                  bdl-olight-m2x-ut.html
#
# Olight Magnetic Charging Cable Kit for the H1 Headlamp
#
# $19.95
#                  olight-mcc-h1-kit.html
#
# Olight Magnetic Charging Cable for R50 Pro and R50 Pro LE
#
# $16.95
#                  olight-r50-pro-mcc.html
#
# Olight H1R Nova Rechargeable Right Angle Headlamp - CREE XM-L2 LED - Cool or Neutral White - 600 Lumens - Includes 1 x 16340
#
# $66.95
#                  olight-h1r-nova-rechargeable-headlamp.html
#
# Olight ORB-186C35 18650 3500mAh 3.6V Protected Lithium Ion (Li-ion) Button Top Battery for the S30R III
#
# $18.99
#                  olight-18650-3500mah-s30riii.html
#
# Olight ORB-163C06 RCR123A / 16340 650mAh 3.7V Protected Lithium Ion (Li-ion) Button Top Battery for S10R III and H1R
#
# $5.50
#                  olight-16340-650mah-s10riii.html
# Olight Replacement Headband for the H1 and H1R Headlamp - Available in Orange, Green or Blue
#
# $6.95
#                  olight-h1-headband.html
#
# Olight Storage Box for the H1 and H1R Headlamp
#
# $7.95
#                  olight-h1-storage-box.html
#
# Olight Holster for the R50, R50 Pro, and R50 Pro LE
#
# $9.95
#                  olight-r50-holster.html
#
# Olight R Dock Magnetic Charger for the R50 Pro and R50 Pro LE
#
# $49.95
#                  olight-r-dock.html
#
# Olight ORB-145P07 14500 750mAh 3.7V Protected Lithium Ion (Li-ion) Button Top Battery - Retail Card
#
# $4.95
#                  olight-14500-750mah.html
#
# Olight ORB-186C26 18650 2600mAh 3.7V Protected High-Drain 4.2A Lithium Ion (Li-ion) Custom Battery for R20 Javelot
#
# $9.99
#                  olight-r20-18650.html
#
# ...
#
# $29.12
#                  sog-fs01n-spirit-spear.html
#
# SOG SOGFari 10-inch Machete - Saw / Straight Edge, Tanto - Hardcased Black Finish - Black Handle - Nylon Sheath - Clam Pack (MC04-N)
#
# $16.89
#                  sog-mc04-10inch-tanto-machete.html
#
# SOG SOGFari 12-inch Kukri Machete - Saw / Straight Edge, Drop Point - Hardcased Black Finish - Black Handle - Nylon Sheath - Clam Pack (MC11-N)
#
# $22.51
#                  sog-mc11-kukri-machete.html
#
# SOG Survival Hawk Axe - 3-inch Straight Edge - Hardcased Black Finish - Black Handle - Nylon Sheath - Clam Pack (SK1001-CP)
#
# $49.95
#                  sog-sk1001-survival-hawk.html
#
# SOG Throwing Hawks with Stamped Nylon Sheath - 1.75-inch Straight Edge, Axe - Hardcased Black Finish - 3 Pack (TH1001-CP)
#
# $49.95
#                  sog-th1001-throwing-hawks.html
#
# SOG Molded Hard Nylon Sheath for FastHawk Axe (HDN-F06)
#
# $19.70
#                  sog-hdn-f06-fasthawk-sheath.html
#
# SOG Elite E-Tool Entrenching Tool / Shovel - Hardcased Black Finish - Black Collapsible Handle - Nylon Sheath - Boxed (F19-N)
#
# $47.27
#                  sog-f19-elite-e-tool.html
#
# SOG Dark Energy DE-03 Tactical Flashlight - 128 Lumens - Uses 1 x AA
#
# $37.15
#                  sog-de-03.html
#
# SOG Dark Energy DE-05 Tactical Flashlight - 624 Lumens - Uses 2 x CR123As
#
# $78.79
#                  sog-de-05.html
#
# SOG Dark Energy DE-06 Tactical Flashlight - 700 Lumens - Uses 1 x 18650
#
# $112.56
#                  sog-de-06.html
#
# SOG Dark Energy DE-01 Tactical Flashlight - 188 Lumens - Uses 1 x CR123A
#
# $51.78
#                  sog-de-01.html
#
# SOG Dark Energy DE-02 Tactical Flashlight - 263 Lumens - Uses 2 x CR123As
#
# $64.16
#                  sog-de-02.html
#
# SOG Tactical Tomahawk Axe - 2.75-inch Straight Edge - Hardcased Black or Polished Finish - Black Handle - Nylon Sheath - Clam Pack (F01TN-CP)
#
# $36.08
#                  sog-tactical-tomahawk.html
#
# SOG FastHawk Axe - 2-inch Straight Edge - Black Finish - Black Handle - Nylon Sheath - Clam Pack (F06TN-CP)
#
# $28.14
#                  sog-f06t-n.html
# Coleman 58032 18 Watt Solar Battery Charger
#
# $76.46
#                  coleman-58032.html
#
# Coleman 58050 55 Watt Solar Charging Kit
#
# $279.95
#                  coleman-58050.html
#
# Coleman 68032 30 Amp Digital Charge Controller
#
# $71.36
#                  coleman-68032.html
#
# Coleman 68022 30 Amp Charge Controller
#
# $67.75
#                  coleman-68022.html
#
# Coleman 58022 6 Watt Trickle Charger
#
# $50.50
#                  coleman-58022.html
#
# Coleman 68012 7 Amp Charge Controller
#
# $19.25
#                  coleman-68012.html
#
# Coleman 58013 1 Watt Solar Sports Charger
#
# $21.50
#                  coleman-58013.html
#
# Coleman 58012 2 Watt Solar Battery Maintainer
#
# $19.95
#                  coleman-58012.html
#
# Coleman 58033 18 Watt Solar Battery Charger Kit with 7 Amp Charge Controller
#
# $102.95
#                  coleman-58033.html
#
# Sunforce 37150 Solar Panel - 150W 8.8 Amp
#
# $420.95
#                  sunforce-37150.html
#
# Sunforce 5 Watt Solar Battery Trickle Charger (50022)
#
# $47.95
#                  sunforce-50022.html
#
# Sunforce Solar  30 Amp Digital Charge Controller (60032)
#
# $79.95
#                  sunforce-60032.html
#
# Sunforce Solar  2500 Watt Pure Sine Wave Pro Series Inverter (11260)
#
# $529.95
#                  sunforce-11260.html
#
# Sunforce Solar AC to DC Converter (55522)
#
# $19.95
#                  sunforce-55522.html
#
# SunForce 1000-Watt Pure Sine Wave Pro Series Inverter (11240)
#
# $234.95
#                  sunforce-11240.html
#
# Sunforce Solar Dock Light (84507)
#
# $23.96
#                  sunforce-84507.html
#
# Sunforce Solar Solar Power Sports Charger (50013)
#
# $24.95
#                  sunforce-50013.html
#
# Sunforce Solar 7 Amp Charge Controller (60012)
#
# $19.95
#                  sunforce-60012.html
#
# Sunforce 1.8 Watt Solar Battery Maintainer (50012)
#
# $17.95
#                  sunforce-50012.html
#
# Sunforce Solar  #4 Gauge Inverter cables for 1000W PSW (11101)
#
# $27.95
#                  sunforce-11101-1.html
#
# Sunforce Solar  #4 Gauge Inverter cables for 2500W PSW - 2 Sets
#
# $54.95
#                  sunforce-11101-2.html
#
# Sunforce Solar  #4 Gauge Inverter cables for 2500W PSW - 4 Sets
#
# $107.95
#                  sunforce-11101-4.html
#
# Sunforce 60 Watt Crystalline Solar Panel (37015)
#
# $424.96
#                  sunforce-37015.html
#
# Sunforce 80 Watt Polycrystalline Solar Panel with Sharp Module (39810)
#
# $479.95
#                  sunforce-39810.html
#
# Sunforce Solar  30' Tower Kit (45455)
#
# $479.95
#                  sunforce-45455.html
#
# Sunforce Solar 60 watt Solar Back up Kit (50048)
#
# $339.95
#                  sunforce-50048.html
#
# Sunforce Solar 8.5 Amp Pro Series Charge Controller (60120)
#
# $49.99
#                  sunforce-60120.html
#
# Sunforce Solar Pest Repeller (80001)
#
# $19.95
#                  sunforce-80001.html
#
# Sunforce Solar 81095 Solar Shed Light  (81095)
#
# $23.95
#                  sunforce-81095.html
#
# Sunforce Solar Flashing Alarm System (86319)
#
# $110.46
#                  sunforce-86319.html
#
# Sunforce 15 Watt Solar Battery Charger Kit with 7 Amp Charge Controller (50033)
#
# $89.95
#                  sunforce-50033-60012.html
#
# Smith Optics - Replacement Lenses for Factor MAX Tactical Sunglasses - Ignitor
#
# $30.00
#                  smith-fmt3ig.html
#
# Smith Optics - Factor Tactical Interchangeable Lens Sunglasses - Black Frames wit Gray,Clear, and Ignitor Lenses - Range Kit
#
# $95.00
#                  smith-fctpc22igbk.html
#
# Smith Optics - Outside The Wire Goggles - Desert Tan Frames with Clear Lenses Installed - Gray Spare Lenses - Field Kit
#
# $68.00
#                  smith-otw01tn-fsb.html
#
# Smith Optics - Outside The Wire Goggles w/ Turbo Fan - Black Frames with Clear Lenses Installed - Gray Spare Lenses - Field Kit
#
# $180.00
#                  smith-otw01bk-tfr.html
#
# Smith Optics Aegis Arc Glasses - Black Frame with Clear, Gray Lens
#
# $80.00
#                  smith-aegabk12-2r.html
#
# Smith Optics Aegis Eyeshields - Desert Tan - Clear and Grey Lenses
#
# $72.25
#                  smith-aeg01-opt.html
#
# Smith Optics - Aegis Eyeshields - Foliage Green Frames with Clear Lenses Installed Gray Spare Lenses - Field Kit
#
# $68.00
#                  smith-aeg01fg-2b.html
#
# Smith Optics - Outside The Wire Goggles - Desert Tan Frames with Clear Lenses Installed - Gray and Yellow Spare Lenses - Deluxe Kit
#
# $80.75
#                  smith-otw01tn-fsdr.html
#
# Smith Optics - Outside The Wire Goggles - Foliage Green Frames with Clear Lenses Installed - Gray and Yellow Spare Lenses - Deluxe Kit
#
# $80.75
#                  smith-otw01fg-fsdr.html
#
# Smith Optics - Outside The Wire Goggles - Black Frames with Clear Lenses Installed - Gray Spare Lenses - Field Kit
#
# $68.00
#                  smith-otw01bk-fsb.html
#
# Smith Optics - Outside The Wire Goggles - Foliage Green Frames with Clear Lenses Installed - Gray Spare Lenses - Field Kit
#
# $80.00
#                  smith-otw01fg-fsb.html
#
# Smith Optics - Interchangeable RX System for Goggles/Eyeshields - Black - Single
#
# $25.00
#                  smith-elrxkit.html
#
# Smith Optics - Outside The Wire Goggles
#
# $72.25
#                  smith-otw01-opt.html
#
# Smith Optics - HIDEOUT Tactical Sunglasses with Black Frames with Gray Lenses
#
# $80.00
#                  smith-hdtpcgy22bk.html
#
# Smith Optics - HIDEOUT Tactical Sunglasses with Black Frames with Ignitor Lenses
#
# $80.00
#                  smith-hdtpcig22bk.html
#
# Smith Optics - HIDEOUT Tactical Sunglasses with Black Frames with Polarized Gray Lenses
#
# $125.00
#                  smith-hdtppgy22bk.html
#
# Smith Optics - DIRECTOR Tactical Sunglasses with Black Frames with Gray Lenses
#
# $80.00
#                  smith-ditpcgy22bk.html
#
# Smith Optics - DIRECTOR Tactical Sunglasses with Black Frames with Ignitor Lenses
#
# $80.00
#                  smith-ditpcig22bk.html
#
# Smith Optics - HUDSON Tactical Sunglasses with Black Frames with Gray Lenses
#
# $80.00
#                  smith-hutpcgy22bk.html
#
# Smith Optics - HUDSON Tactical Sunglasses with Black Frames with Ignitor Lenses
#
# $80.00
#                  smith-hutpcig22bk.html
#
# Smith Optics - HUDSON Tactical Sunglasses with Black Frames with Polarized Gray Lenses
#
# $125.00
#                  smith-hutppgy22bk.html
#
# Smith Optics - HUDSON Tactical Sunglasses with Black Frames with Clear Lenses
#
# $80.00
#                  smith-hutpccl22bk.html
#
# Smith Optics - CHAMBER Tactical Sunglasses with Black Frames with Gray Lenses
#
# $80.00
#                  smith-crtpcgy22bk.html
#
# Smith Optics - CHAMBER Tactical Sunglasses with Black Frames with Ignitor Lenses
#
# $80.00
#                  smith-crtpcig22bk.html
#
# Smith Optics - Factor Tactical Interchageable Lens Sunglasses - Black Frames wit Gray and Clear Lenses - Field Kit
#
# $85.00
#                  smith-fctpc22gybk.html
#
# Smith Optics - CHAMBER Tactical Sunglasses with Black Frames with Clear Lenses
#
# $80.00
#                  smith-crtpccl22bk.html
#
# Smith Optics - HIDEOUT Tactical Sunglasses with Black Frames with Clear Lenses
#
# $80.00
#                  smith-hdtpccl22bk.html
#
# Smith Optics - DIRECTOR Tactical Sunglasses with Black Frames with Clear Lenses
#
# $80.00
#                  smith-ditpccl22bk.html
#
# Smith Optics - Aegis Eyeshield Replacement Lenses - Gray Single
#
# $20.00
#                  smith-aeglnsgy.html
#
# Smith Optics - Aegis Eyeshield Replacement Lenses - Ignitor Single
#
# $20.00
#                  smith-aeglnsig.html
#
# Smith Optics - Aegis Eyeshield Replacement Lenses - Yellow Single
#
# $20.00
#                  smith-aeglnsab.html
#
# Smith Optics - Aegis Eyeshield Replacement Lenses - Clear Single
#
# $20.00
#                  smith-aeglnscl.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Gray - Single
#
# $20.00
#                  smith-otw01y.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Ignitor - Single
#
# $17.00
#                  smith-otw01ig.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Yellow - Single
#
# $20.00
#                  smith-otw01a.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Clear - Single
#
# $20.00
#                  smith-otw01c.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Turbo Gray - Single Turbo
#
# $20.00
#                  smith-otw01y-tf.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Turbo Yellow - Single Turbo
#
# $20.00
#                  smith-otw01a-tf.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Turbo Clear - Single Turbo
#
# $20.00
#                  smith-otw01c-tf.html
#
# Smith Optics - Outside The Wire Goggle Replacement Lenses - Turbo Ignitor - Single Turbo
#
# $20.00
#                  smith-otw01ig-tf.html
#
# Smith Optics - Replacement Strap for OTW Goggles - Black
#
# $25.00
#                  smith-otwstrap-bk.html
#
# Smith Optics - Replacement Strap for OTW Goggles - Foliage Green
#
# $25.00
#                  smith-otwstrap-fg.html
#
# Smith Optics - Protective Sleeve for OTW Goggles - Black
#
# $12.00
#                  smith-egarslv-bk.html
#
# Smith Optics - Protective Sleeve for OTW Goggles - Foliage Green
#
# $12.00
#                  smith-egarslv-fg.html
#
# Smith Optics - Protective Sleeve for OTW Goggles - Universal Camo
#
# $10.20
#                  smith-egarslv-cm.html
#
# Smith Optics - Case for OTW Goggles - Black
#
# $20.00
#                  smith-otwglbag-bk.html
#
# Smith Optics - Case for Aegis Eyeshield - Black
#
# $20.00
#                  smith-aegcsbk.html
# Wiley X Revolvr Sunglasses with High Velocity Protection Street Series in Various Color Schemes (SSREV3)
#
# $85.50
#                  wileyx-revolvr-opt.html
#
# Wiley X (A425) Eyeglass Microfiber Cleaning Cloth - Boxed
#
# $2.70
#                  wiley-x-micro-fiber-cleaning-cloth.html
#
# Wiley X WX Valor Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (CHVAL01 CHVAL02 CHVAL04 CHVAL06)
#
# $67.50
#                  wileyx-wx-valor-opt.html
#
# Wiley X AirRage Sunglasses with High Velocity Protection Climate Control Series in Various Color Schemes (693 694 695 696 697 698 699)
#
# $78.30
#                  wileyx-airrage-opt.html
#
# Wiley X WX Gravity Sunglasses with High Velocity Protection Climate Control Series in Various Color Schemes (CCGRA01 CCGRA04 CCGRA05 CCGRA06 )
#
# $78.30
#                  wileyx-wx-gravity-opt.html
#
# Wiley X Brick Sunglasses with High Velocity Protection Climate Control Series in Various Color Schemes (853 854 855 856 857)
#
# $78.30
#                  wileyx-brick-opt.html
#
# Wiley X WX Echo Sunglasses with High Velocity Protection Climate Control Series in Various Color Schemes (CCECH01 CCECH04 CCECH05)
#
# $78.30
#                  wileyx-wx-echo-opt.html
#
# Wiley X WX Twisted Sunglasses with High Velocity Protection Street Series in Various Color Schemes (SSTWI01)
#
# $85.50
#                  wileyx-wx-twisted-opt.html
#
# Wiley X Romer III Advanced Changeable Sunglasses Rx Ready with High Velocity Protection - Matte Black Frame with Smoke Grey - Clear Lens Kit (1004)
#
# $75.60
#                  wileyx-romer-iii.html
#
# Wiley X Sunglasses Saber Advanced with High Velocity Protection in Various Color Schemes (300 301 302 302RX 303 303RX 306 306RX 307 307RX 309 309RX)
#
# $34.20
#                  wileyx-saber-advanced-opt.html
#
# Wiley X Zak Sunglasses with High Velocity Protection Active Series in Various Color Schemes (ACZAK06 ACZAK04 ACZAK07 ACZAK08)
#
# $122.50
#                  wileyx-zak-opt.html
#
# Wiley X P-17 Sunglasses with High Velocity Protection Active Series in Various Color Schemes (P-17NP P-17M P-17 P-17GM)
#
# $71.95
#                  wileyx-p-17-opt.html
#
# Wiley X Sunglasses Slay with High Velocity Protection in Various Color Schemes (ACSLA01 ACSLA04)
#
# $75.00
#                  wileyx-slay-opt.html
#
# Wiley X WX Censor Street Sunglasses Rx Ready with High Velocity Protection - Black Ops Matte Black Frame with Smoke Grey Lenses (SSCEN01)
#
# $95.00
#                  wileyx-wx-censor-opt.html
#
# Wiley X XL-1 Advanced Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (291 292 297)
#
# $75.60
#                  wileyx-xl-1-advanced-opt.html
#
# Wiley X Romer III Advanced Changeable Sunglasses Rx Ready with High Velocity Protection - Matte Black Frame with Smoke Grey - Clear - Light Rust Lens Kit (1006)
#
# $86.60
#                  wileyx-romer-ii-advanced-opt.html
#
# Wiley X Guard Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (4004 4006)
#
# $63.00
#                  wileyx-guard-opt.html
#
# Wiley X WX Talon Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (CHTAL1 CHTAL1RX CHTAL2 CHTAL2RX)
#
# $85.50
#                  wileyx-wx-talon-opt.html
#
# Wiley X PT-1 Sunglasses with High Velocity Protection Changeable Series in Various Color Schemes (PT-1S PT-1SRX PT-1C PT-1CRX PT-1L PT-1LRX PT-1SC PT-1SCRX PT-1SCL PT-1SCLRX )
#
# $63.00
#                  wileyx-pt-1-opt.html
#
# Wiley X SG-1 Goggles with High Velocity Protection in Various Color Schemes (70 71 SG-1M 77)
#
# $102.60
#                  wileyx-sg-1-opt.html
#
# Wiley X Nerve Goggles with High Velocity Protection in Various Color Schemes (R-8051 R-8051T R-8051G R-8051RX)
#
# $84.60
#                  wileyx-nerve-opt.html
#
# Method Lights ML200 Plus Wireless LED Picture Light Fixture - 450 Lumens - Lithium Ion Battery Pack (Li-Ion) - Includes Remote Control, AC Adapter, and Installation Hardware
#
# $290.00
#                  method-lights-ml200-plus.html
#
# Method Lights ML-Direct Plus LED Picture Light - 1280 Lumens - Includes Remote Control - Bulb Compatible with Recessed and Track Lighting Fixtures
#
# $130.00
#                  method-lights-ml-direct-plus.html
#
# Method Lights ML200 Wireless LED Picture Light Fixture - 870 Lumens - Lithium Ion Battery Pack (Li-Ion) - Includes Remote Control, AC Adapter, and Installation Hardware
#
# $274.95
#                  method-ml200.html
#
# Method Lights ML-Direct LED Picture Light - 1700 Lumens - Includes Remote Control - Bulb Compatible with Recessed and Track Lighting Fixtures
#
# $119.95
#                  method-ml-direct.html
#
# Method Lights ML-EZ Charger Kit for ML200 Picture Lights - Includes Magnetic Charging Cable, Adapter, and Extendable Arm
#
# $49.95
#                  method-ml-ez.html

# %%
# Out:
# ['klarus-january-promo.html',
#  '2017-hunting-gear.html',
#  '2017-olight-discounts40.html',
#  'bargain-bundles.html',
#  'clearance.html',
#  'olt20t15t10.html',
#  'fenix.html',
#  'surefire.html',
#  'nitecore.html',
#  'jetbeam.html',
#  'sunwayled.html',
#  'lightstar-corp.html',
#  'klarus.html',
#  'stfl.html',
#  'titanium.html',
#  'coast.html',
#  'pelican.html',
#  'underwater-kinetics-lights.html',
#  'powertac.html',
#  'petzl.html',
#  'asp.html',
#  'flashlight-brands.html',
#  'flashlight-edc.html',
#  'flashlight-head.html',
#  'intrinsically-safe-lights.html',
#  'flashlight-key.html',
#  'lanterns.html',
#  'flashlight-pen.html',
#  'rechargeable-.html',
#  'right-angle-flashlights.html',
#  'flashlight-search.html',
#  'flashlight-tactical.html',
#  'flashlight-uv.html',
#  'weapon-lights.html',
#  'flashlight-accessories.html',
#  'flashlight-type.html',
#  'bike-lighting.html',
#  'marine-flashlights.html',
#  'camping-flashlights-lanterns.html',
#  'caving-spelunking-flashlights.html',
#  'climbing-flashlights.html',
#  'dive-lights.html',
#  'hiking-flashlights.html',
#  'around-the-house-flashlights.html',
#  'hunting-flashlights.html',
#  'law-enforcement-security-flashlights.html',
#  'photography-flashlights.html',
#  'pilot-flashlights.html',
#  'running-lights.html',
#  'travel-flashlights.html',
#  'light-for-walking-at-night.html',
#  'winter-sports-flashlights.html',
#  'portable-work-lights.html',
#  'flashlight-uses.html',
#  'flashlights-aa.html',
#  'flashlights-aaa.html',
#  'flashlights-cr123a.html',
#  'flashlights-16340.html',
#  'flashlights-18650.html',
#  '26650-flashlights.html',
#  'flashlights-aaaa.html',
#  'flashlights-cr2.html',
#  'flashlights-c.html',
#  'flashlights-d.html',
#  'flashlights-coin.html',
#  'flashlights-packs.html',
#  'sla-flashlights.html',
#  'flashlight-power.html',
#  'batteries-size-cr123a.html',
#  '18650.html',
#  'batteries-size-aa.html',
#  'aaanireba.html',
#  'batteries-size-c.html',
#  'batteries-size-d.html',
#  'batteries-size-9v.html',
#  'button-coin-cells.html',
#  'hearing-aid-batteries.html',
#  'batt-packs.html',
#  'batteries-size-16340.html',
#  '14500-category.html',
#  '10440-category.html',
#  'batteries-size-cr2.html',
#  'battery-sizes.html',
#  'batteries-chemistry-alkaline.html',
#  'batteries-chemistry-ni-mh.html',
#  'batteries-chemistry-lithium.html',
#  'liion-cat.html',
#  'batteries-chemistry-lithium-thionyl-chloride.html',
#  'batteries-chemistry-li-poly.html',
#  'batteries-chemistry-ni-cd.html',
#  'batteries-chemistry-silver-oxide.html',
#  'batteries-chemistry-zinc-air.html',
#  'batteries-chemistry-zinc.html',
#  'batteries-chemistry-sla.html',
#  'battery-chemistries.html',
#  'batteries-brand-duracell.html',
#  'batteries-brand-energizer.html',
#  'batteries-brand-panasonic.html',
#  'batteries-brand-tenergy.html',
#  'batteries-brand-titanium.html',
#  'batteries-brand-sony.html',
#  'batteries-brand-xtar.html',
#  'batteries-brand-ultrafire.html',
#  'eneloop-batteries.html',
#  'batteries-brand-maxell.html',
#  'batteries-brand-rayovac.html',
#  'tadiran.html',
#  'battery-brands.html',
#  'batteries-voltage-3v.html',
#  'batteries-voltage-1v5.html',
#  'batteries-voltage-3v7.html',
#  'batteries-voltage-9v.html',
#  'batteries-voltage-1v2.html',
#  'batteries-voltage-1v55.html',
#  'batteries-voltage-12v.html',
#  'batteries-voltage-8v4.html',
#  'batteries-voltage-7v4.html',
#  'batteries-voltage-6v.html',
#  'batteries-voltage-9v6.html',
#  'battery-voltages.html',
#  'primary-batteries.html',
#  'rechargeable-batteries.html',
#  'all-coin-cells.html',
#  'pri-bulk.html',
#  'baadandca.html',
#  'all-testers.html',
#  'shrink-wrapped-batteries.html',
#  'xfhbattery.html',
#  'home-security-system-batteries.html',
#  'flashlight-battery-packs.html',
#  'hearing-aid-batteries.html',
#  'defibrillator-batteries.html',
#  'camera-batteries-and-accessories.html',
#  '/2-way-radio-batteries.html',
#  'ln-batteries.html',
#  '12-best-chargers.html',
#  'lithium-chargers.html',
#  'smchseaaaaac.html',
#  'recrbachrc.html',
#  'cochco.html',
#  'battery-pack-chargers.html',
#  'power-banks.html',
#  'chargers1.html',
#  'sunforce.html',
#  'colemansolar.html',
#  'wagan-solar.html',
#  'solarpower.html',
#  '12-accessories.html',
#  'plugadapters.html',
#  'ac11ac22in.html',
#  'all-testers.html',
#  'ac-wall-chargers.html',
#  'cell-phone-charger.html',
#  'laptop-power-supplies.html',
#  'flashlight-chargers.html',
#  'charger-accessories.html',
#  'cutlery.html',
#  'bags-and-packs.html',
#  'protective-storage-case.html',
#  'solar.html',
#  'optics.html',
#  'outdoor-gear.html',
#  'jewelry-cleaning.html',
#  'vape-accessories.html',
#  'niteite-hard.html',
#  'cell-phone-accessories.html',
#  'gear-type.html',
#  'nipr.html',
#  'wagan.html',
#  'gunbutter.html',
#  'retrak.html',
#  'maxpedition-hard-use-gear.html',
#  'underwater-kinetics.html',
#  'pelican-cases.html',
#  'steripen.html',
#  'cyalume-signaling-products.html',
#  'gemoro.html',
#  'fenix-ruike-tactical-knives-tools.html',
#  'ust.html',
#  'revere-liferafts.html',
#  'leatherman.html',
#  'sog.html',
#  'colemansolar.html',
#  'sunforce.html',
#  'smithoptics.html',
#  'wileyx.html',
#  'method-lights.html',
#  'gear-brand.html']
