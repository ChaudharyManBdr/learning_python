# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,6])

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# dtype: int64

# %%
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# dtype: int64

# %%
data = pd.read_csv('C:/Users/mbchaudhary/Documents/learning_python/gbd_csv_task/contact_export_122617_2010.csv')

# %%
data
# Out:
#          First name    Last name          Email address - other
# 0             tracy    alexander          tracycarjam@yahoo.com
# 1              Dale    Arrington             jarring360@aol.com
# 2             Peggy        Adams         adamsbts@bellsouth.net
# 3             Stacy       Adkins         stacy.adkins@yahoo.com
# 4               Jen          Ahm                boithol@aol.com
# 5               Jan        Adams                  naj43@aol.com
# 6           Charity  Aughinbaugh  charity.aughinbaugh@gmail.com
# 7             stacy        adams          stacy_adams@yahoo.com
# 8           Jessica        Adair       millertime79@hotmail.com
# 9          jennifer      ANGELLE           jennifer@angelle.com
# 10            suzie        allen         sueallen54@comcast.net
# 11           Sharon       Armijo         armijos@nationwide.com
# 12          Claudia       Araujo               czraraujo@me.com
# 13           Sharna        Adams      larryadams@windstream.net
# ...

# %%
data_f = pd.DataFrame(data)

# %%
data_f.describe()
# Out:
#        First name Last name Email address - other
# count       14142     13852                 22802
# unique       4224      9183                 22790
# top      Jennifer     Smith      Kdavid57@cox.net
# freq          267       110                     2

# %%
data_f.head()
# Out:
#   First name  Last name   Email address - other
# 0      tracy  alexander   tracycarjam@yahoo.com
# 1       Dale  Arrington      jarring360@aol.com
# 2      Peggy      Adams  adamsbts@bellsouth.net
# 3      Stacy     Adkins  stacy.adkins@yahoo.com
# 4        Jen        Ahm         boithol@aol.com

# %%
data_1 = pd.read_csv('C:/Users/mbchaudhary/Documents/learning_python/gbd_csv_task/pd_final.csv')

# %%
data_1
# Out:
#                   date                           email          bill-name  \
# 0        1/1/2017 9:29         christinecaputo@aol.com   Christine Caputo
# 1        1/1/2017 9:50           phyllismackey@att.net     Phyllis Mackey
# 2        1/1/2017 9:50           phyllismackey@att.net     Phyllis Mackey
# 3        1/1/2017 9:50           phyllismackey@att.net     Phyllis Mackey
# 4       1/1/2017 15:16          kathysgreene@yahoo.com       KATHY GREENE
# 5       1/1/2017 15:16          kathysgreene@yahoo.com       KATHY GREENE
# 6       1/1/2017 15:16          kathysgreene@yahoo.com       KATHY GREENE
# 7       1/1/2017 15:16          kathysgreene@yahoo.com       KATHY GREENE
# 8       1/2/2017 11:01  judyandjonathan@rocketmail.com          Judy Cole
# 9       1/2/2017 15:19            catvazquez@yahoo.com  catherine vazquez
# 10      1/2/2017 15:19            catvazquez@yahoo.com  catherine vazquez
# 11       1/3/2017 4:36       jessica.dzara@hotmail.com      Jessica Dzara
# ...

# %%
data_2 = pd.read_csv('C:/Users/mbchaudhary/Documents/learning_python/gbd_csv_task/bestdressedchild-280225-302409.csv', error_bad_lines=False, encoding="ISO-8859-1")
# Out:
# b'Skipping line 240: expected 54 fields, saw 57\nSkipping line 400: expected 54 fields, saw 57\nSkipping line 452: expected 54 fields, saw 89\nSkipping line 561: expected 54 fields, saw 63\nSkipping line 896: expected 54 fields, saw 60\nSkipping line 1481: expected 54 fields, saw 63\nSkipping line 1994: expected 54 fields, saw 65\nSkipping line 2091: expected 54 fields, saw 59\nSkipping line 4193: expected 54 fields, saw 73\nSkipping line 4451: expected 54 fields, saw 63\nSkipping line 6665: expected 54 fields, saw 73\nSkipping line 7115: expected 54 fields, saw 62\nSkipping line 7918: expected 54 fields, saw 63\nSkipping line 8113: expected 54 fields, saw 61\nSkipping line 8569: expected 54 fields, saw 59\nSkipping line 9729: expected 54 fields, saw 65\nSkipping line 10230: expected 54 fields, saw 62\nSkipping line 10343: expected 54 fields, saw 105\nSkipping line 10355: expected 54 fields, saw 71\nSkipping line 10391: expected 54 fields, saw 58\nSkipping line 10804: expected 54 fie
# ...

# %%
data_2
# Out:
#            Id                    ProId                      Date        Time  \
# 0      280225  bestdressedchild-280225  Fri Jan  1 00:22:21 2016  1451636541
# 1      280226  bestdressedchild-280226  Fri Jan  1 05:30:44 2016  1451655044
# 2      280227  bestdressedchild-280227  Fri Jan  1 07:02:35 2016  1451660555
# 3      280228  bestdressedchild-280228  Fri Jan  1 07:11:15 2016  1451661075
# 4      280229  bestdressedchild-280229  Fri Jan  1 07:17:41 2016  1451661461
# 5      280230  bestdressedchild-280230  Fri Jan  1 07:24:15 2016  1451661855
# 6      280231  bestdressedchild-280231  Fri Jan  1 07:45:21 2016  1451663121
# 7      280232  bestdressedchild-280232  Fri Jan  1 08:07:01 2016  1451664421
# 8      280233  bestdressedchild-280233  Fri Jan  1 08:19:26 2016  1451665166
# 9      280234  bestdressedchild-280234  Fri Jan  1 08:20:35 2016  1451665235
# 10     280235  bestdressedchild-280235  Fri Jan  1 08:27:07 2016  1451665627
# ...

# %%
data_2 = pd.read_csv('C:/Users/mbchaudhary/Documents/learning_python/gbd_csv_task/bestdressedchild-280225-302409.csv',header=None, usecols=[2,16,26,33,34,35,36,37,38,39,40],  error_bad_lines=False, encoding="ISO-8859-1")
# Out:
# C:\Users\mbchaudhary\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_2
# Out:
#                              2                     16  \
# 0                          Date             bill-name
# 1      Fri Jan  1 00:22:21 2016       elisabeth short
# 2      Fri Jan  1 05:30:44 2016       Margaret Warren
# 3      Fri Jan  1 07:02:35 2016           Sarah Kelly
# 4      Fri Jan  1 07:11:15 2016      Melissa McMullen
# 5      Fri Jan  1 07:17:41 2016           Emily Jones
# 6      Fri Jan  1 07:24:15 2016           Wanda McKay
# 7      Fri Jan  1 07:45:21 2016         Kendra Fuller
# 8      Fri Jan  1 08:07:01 2016        Laura Thompson
# 9      Fri Jan  1 08:19:26 2016          Annette Huss
# 10     Fri Jan  1 08:20:35 2016           diane bates
# 11     Fri Jan  1 08:27:07 2016       Patricia Harper
# 12     Fri Jan  1 08:33:20 2016         Carrie Hodges
# 13     Fri Jan  1 09:00:32 2016             Debi Akin
# 14     Fri Jan  1 09:13:11 2016             Debi Akin
# 15     Fri Jan  1 09:39:40 2016           Tammy Adams
# ...

# %%
data_2.at[2,34]
# Out:
# 'Cukees Infant / Toddler Boys Light Blue Check Smocked Crosses Overall|cuintobolibl|CU-1062O-CK13|1|33.99|cuintobolibl'

# %%
data_1.at[2,'Item Purchased']
# Out:
# 'Claire & Charlie Girls Blue / Red Floral Sunflowers Smocked Bishop Dress'
