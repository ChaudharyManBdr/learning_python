# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
from urllib.request import HTTPError

# %%
html = urlopen('https://www.batteryjunction.com/')

# %%
html

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# free-shipping-popup.html
# service.html
# knowledge-center.html
# service.html
# order-status.html
# shipping-info.html
# contact.html
# coupons.html
# http://myaccount.batteryjunction.com/
# javascript:;
# http://myaccount.batteryjunction.com/
# index.html
# http://myaccount.batteryjunction.com/
# deals.html
# deals.html
# klarus-january-promo.html
# 2017-hunting-gear.html
# 2017-olight-discounts40.html
# bargain-bundles.html
# clearance.html
# deals.html
# deals.html
# ln-flashlights.html
# flashlight-brands.html
# olt20t15t10.html
# fenix.html
# surefire.html
# nitecore.html
# jetbeam.html
# sunwayled.html
# lightstar-corp.html
# klarus.html
# stfl.html
# titanium.html
# coast.html
# pelican.html
# underwater-kinetics-lights.html
# powertac.html
# petzl.html
# asp.html
# flashlight-brands.html
# flashlight-type.html
# flashlight-edc.html
# flashlight-head.html
# intrinsically-safe-lights.html
# flashlight-key.html
# lanterns.html
# flashlight-pen.html
# rechargeable-.html
# right-angle-flashlights.html
# flashlight-search.html
# flashlight-tactical.html
# flashlight-uv.html
# weapon-lights.html
# flashlight-accessories.html
# flashlight-type.html
# flashlight-uses.html
# bike-lighting.html
# marine-flashlights.html
# camping-flashlights-lanterns.html
# caving-spelunking-flashlights.html
# climbing-flashlights.html
# dive-lights.html
# hiking-flashlights.html
# around-the-house-flashlights.html
# hunting-flashlights.html
# law-enforcement-security-flashlights.html
# photography-flashlights.html
# pilot-flashlights.html
# running-lights.html
# travel-flashlights.html
# light-for-walking-at-night.html
# winter-sports-flashlights.html
# portable-work-lights.html
# flashlight-uses.html
# flashlight-power.html
# flashlights-aa.html
# flashlights-aaa.html
# flashlights-cr123a.html
# flashlights-16340.html
# flashlights-18650.html
# 26650-flashlights.html
# flashlights-aaaa.html
# flashlights-cr2.html
# flashlights-c.html
# flashlights-d.html
# flashlights-coin.html
# flashlights-packs.html
# sla-flashlights.html
# flashlight-power.html
# flashlight-brands.html
# flashlights-all.html
# ln-batteries.html
# battery-sizes.html
# batteries-size-cr123a.html
# 18650.html
# batteries-size-aa.html
# aaanireba.html
# batteries-size-c.html
# batteries-size-d.html
# batteries-size-9v.html
# button-coin-cells.html
# hearing-aid-batteries.html
# batt-packs.html
# batteries-size-16340.html
# 14500-category.html
# 10440-category.html
# batteries-size-cr2.html
# battery-sizes.html
# battery-chemistries.html
# batteries-chemistry-alkaline.html
# batteries-chemistry-ni-mh.html
# batteries-chemistry-lithium.html
# liion-cat.html
# batteries-chemistry-lithium-thionyl-chloride.html
# batteries-chemistry-li-poly.html
# batteries-chemistry-ni-cd.html
# batteries-chemistry-silver-oxide.html
# batteries-chemistry-zinc-air.html
# batteries-chemistry-zinc.html
# batteries-chemistry-sla.html
# battery-chemistries.html
# battery-brands.html
# batteries-brand-duracell.html
# batteries-brand-energizer.html
# batteries-brand-panasonic.html
# batteries-brand-tenergy.html
# batteries-brand-titanium.html
# batteries-brand-sony.html
# batteries-brand-xtar.html
# batteries-brand-ultrafire.html
# eneloop-batteries.html
# batteries-brand-maxell.html
# batteries-brand-rayovac.html
# tadiran.html
# battery-brands.html
# battery-voltages.html
# batteries-voltage-3v.html
# batteries-voltage-1v5.html
# batteries-voltage-3v7.html
# batteries-voltage-9v.html
# batteries-voltage-1v2.html
# batteries-voltage-1v55.html
# batteries-voltage-12v.html
# batteries-voltage-8v4.html
# batteries-voltage-7v4.html
# batteries-voltage-6v.html
# batteries-voltage-9v6.html
# battery-voltages.html
# ln-batteries.html
# primary-batteries.html
# rechargeable-batteries.html
# all-coin-cells.html
# pri-bulk.html
# baadandca.html
# all-testers.html
# shrink-wrapped-batteries.html
# ln-batteries.html
# camera-batteries-and-accessories.html
# cell-phone-batteries.html
# defibrillator-batteries.html
# hearing-aid-batteries.html
# home-security-system-batteries.html
# remote-control-batteries.html
# xfhbattery.html
# ln-batteries.html
# tpen-tcr123a-.html
# batteries-all.html
# ln-accessories.html
# chargers1.html
# 12-best-chargers.html
# lithium-chargers.html
# smchseaaaaac.html
# recrbachrc.html
# cochco.html
# battery-pack-chargers.html
# power-banks.html
# chargers1.html
# solarpower.html
# sunforce.html
# colemansolar.html
# wagan-solar.html
# solarpower.html
# charger-accessories.html
# 12-accessories.html
# plugadapters.html
# ac11ac22in.html
# all-testers.html
# ac-wall-chargers.html
# cell-phone-charger.html
# laptop-power-supplies.html
# flashlight-chargers.html
# charger-accessories.html
# nitecore-d4-digicharger.html
# chargers-all.html
# ln-gear.html
# gear-type.html
# cutlery.html
# bags-and-packs.html
# protective-storage-case.html
# solar.html
# optics.html
# outdoor-gear.html
# jewelry-cleaning.html
# vape-accessories.html
# niteite-hard.html
# cell-phone-accessories.html
# gear-type.html
# gear-brand.html
# nipr.html
# wagan.html
# gunbutter.html
# retrak.html
# maxpedition-hard-use-gear.html
# underwater-kinetics.html
# pelican-cases.html
# steripen.html
# cyalume-signaling-products.html
# gemoro.html
# fenix-ruike-tactical-knives-tools.html
# ust.html
# revere-liferafts.html
# leatherman.html
# sog.html
# colemansolar.html
# sunforce.html
# smithoptics.html
# wileyx.html
# method-lights.html
# gear-brand.html
# ln-gear.html
# gear-all.html
# new-items.html
# wholesale.html
# #eci-ln-flashlights.html
# #eci-ln-batteries.html
# #eci-ln-gear.html
# #eci-new-items.html
# http://order.store.yahoo.net/theshorelinemarket/cgi-bin/wg-order?theshorelinemarket
# ln-batteries.html
# batteries-all.html
# battery-sizes.html
# battery-chemistries.html
# battery-brands.html
# battery-voltages.html
# ln-batteries.html
# ln-flashlights.html
# flashlights-all.html
# flashlight-brands.html
# flashlight-type.html
# flashlight-uses.html
# flashlight-power.html
# deals.html
# deals.html
# klarus-january-promo.html
# 2017-hunting-gear.html
# 2017-olight-discounts40.html
# bargain-bundles.html
# clearance.html
# search-results.html?&search_return=all#/?search_return=all&Catalogpdrating=5+Star
# 2015-10-favorites-landing.html
# gifts-for-kids.html
# 12-best-chargers.html
# ln-accessories.html
# chargers-all.html
# chargers1.html
# solarpower.html
# charger-accessories.html
# ln-gear.html
# gear-all.html
# gear-brand.html
# gear-type.html
# new-items.html
# best-sellers.html
# search-results.html?&search_return=all#/?search_return=all&Catalogpdrating=5+Star
# new-items.html
# lifetime-warranty.html
# 2015-10-favorites-landing.html
# gifts-for-kids.html
# 12-best-chargers.html
# wholesale.html
# https://www.batteryjunction.com/klarus-january-promo.html?utm_source=2018-1-11KlarusSaleBanner&utm_medium=rotator_homepage&utm_campaign=responsiveTemplate
# https://www.batteryjunction.com/nitecore-br35-bike-light.html?utm_source=2018-1-11NitecoreBR35Banner&utm_medium=rotator_homepage&utm_campaign=responsiveTemplate
# https://www.batteryjunction.com/fenix-uc52-oled-screen-handheld-led-flashlight.html?utm_source=2018-1-5FenixUC52Banner&utm_medium=rotator_homepage&utm_campaign=responsiveTemplate
# https://www.batteryjunction.com/nitecore-mh23-rechargeable-flashlight.html?utm_source=2018-1-5NitecoreMH23Banner&utm_medium=rotator_homepage&utm_campaign=responsiveTemplate
# https://www.batteryjunction.com/sf-flashlights.html?utm_source=2017-9-7SureFireBatteryPromoHome&utm_medium=rotator_homepage&utm_campaign=responsiveTemplate
# https://www.batteryjunction.com/new-items.html?utm_source=2014_9_17_HotProds&utm_medium=rotator_homepage&utm_campaign=2014_9_17_HotProds
# https://www.batteryjunction.com/coupons.html?utm_source=2013_12_26_savingsClubPromo&utm_medium=rotator_homepage&utm_campaign=2013_12_26_savingsClubPromo
# tpen-tcr123a-.html
# #
# klarus-st10-rechargeable-led-flashlight.html?utm_source=1-16-2018-KLARUS-ST10-HERO&utm_medium=ysw_home_block_6&utm_campaign=responsiveTemplate
# olight-s1-mini-baton-edc-flashlight.html?utm_source=12-28-2017-OLIGHT-S1-MINI-HERO&utm_medium=ysw_home_block_7&utm_campaign=responsiveTemplate
# ln-flashlights.html
# olight-valkyrie.html
# olight-valkyrie.html
# nitecore-ec23-led-flashlight.html
# nitecore-ec23-led-flashlight.html
# nitecore-hc60-headlamp.html
# nitecore-hc60-headlamp.html
# sunwayman-t20cc-opt.html
# sunwayman-t20cc-opt.html
# klarus-xt2cr-tactical-flashlight.html
# klarus-xt2cr-tactical-flashlight.html
# olight-m2r-tactical-led-flashlight.html
# olight-m2r-tactical-led-flashlight.html
# klarus-mini-one-ti-keychain-light.html
# klarus-mini-one-ti-keychain-light.html
# klarus-xt11gt-hd-flashlight.html
# klarus-xt11gt-hd-flashlight.html
# olight-s30r-iii.html
# olight-s30r-iii.html
# fenix-hl40r-focusable-led-headlamp.html
# fenix-hl40r-focusable-led-headlamp.html
# nitecore-tini.html
# nitecore-tini.html
# ln-batteries.html
# pc-1500.html
# pc-1500.html
# titanium-innovations-9-volt-lithium-1pk.html
# titanium-innovations-9-volt-lithium-1pk.html
# energizer-l91aa.html
# energizer-l91aa.html
# cr2032.html
# cr2032.html
# energizer-ecr1632.html
# energizer-ecr1632.html
# duraacell-cr123a.html
# duraacell-cr123a.html
# encocebaeccr4.html
# encocebaeccr4.html
# mn-2400.html
# mn-2400.html
# energizer-ecr2450bp.html
# energizer-ecr2450bp.html
# ln-gear.html
# pelican-0u1050-0003-110.html
# pelican-0u1050-0003-110.html
# sog-b66-n.html
# sog-b66-n.html
# nitecore-nws10.html
# nitecore-nws10.html
# ust-20-310-455c.html
# ust-20-310-455c.html
# ust-20-310-173.html
# ust-20-310-173.html
# safety-belt.html
# safety-belt.html
# nitecore-bp20-multi-purpose-backpack.html
# nitecore-bp20-multi-purpose-backpack.html
# ust-20-310-116.html
# ust-20-310-116.html
# ust-20-pgr0001-08.html
# ust-20-pgr0001-08.html
# new-items.html
# fenix-tk25-red-led-flashlight.html
# fenix-tk25-red-led-flashlight.html
# fenix-tk35ue-multi-functional-led-flashlight.html
# fenix-tk35ue-multi-functional-led-flashlight.html
# sunwayman-c41ct-rechargeable-led-flashlight.html
# sunwayman-c41ct-rechargeable-led-flashlight.html
# nitecore-hc65-led-headlamp.html
# nitecore-hc65-led-headlamp.html
# olight-s1-mini-baton-edc-flashlight.html
# olight-s1-mini-baton-edc-flashlight.html
# fenix-hl32r-rechargeable-headlamp.html
# fenix-hl32r-rechargeable-headlamp.html
# jetbeam-sf-aa01-edc-flashlight.html
# jetbeam-sf-aa01-edc-flashlight.html
# klarus-st10-rechargeable-led-flashlight.html
# klarus-st10-rechargeable-led-flashlight.html
# titanium-innovations-9-volt-lithium-10-box.html
# titanium-innovations-9-volt-lithium-10-box.html
# https://www.facebook.com/BatteryJunction
# https://twitter.com/batteryjunction
# https://plus.google.com/+BatteryjunctionHangOut/about
# https://www.youtube.com/user/BatteryJunction
# https://www.instagram.com/batteryjunction/
# http://myaccount.batteryjunction.com/
# http://blog.batteryjunction.com/
# knowledge-center.html
# gift-certificates.html
# shipping-info.html
# privacypolicy.html
# contact.html
# order-status.html
# service.html#returns
# fixes.html
# service.html
# ind.html
# wholesale.html
# service.html
# http://myaccount.batteryjunction.com/
# knowledge-center.html
# shipping-info.html
# order-status.html
# wholesale.html
# //www.resellerratings.com
# deals.html
# deals.html
# klarus-january-promo.html
# 2017-hunting-gear.html
# 2017-olight-discounts40.html
# bargain-bundles.html
# clearance.html
# search-results.html?&search_return=all#/?search_return=all&Catalogpdrating=5+Star
# 2015-10-favorites-landing.html
# gifts-for-kids.html
# 12-best-chargers.html
# ln-flashlights.html
# flashlights-all.html
# flashlight-brands.html
# flashlight-type.html
# flashlight-uses.html
# flashlight-power.html
# ln-batteries.html
# batteries-all.html
# battery-sizes.html
# battery-chemistries.html
# battery-brands.html
# battery-voltages.html
# ln-batteries.html
# ln-accessories.html
# chargers-all.html
# chargers1.html
# solarpower.html
# charger-accessories.html
# ln-gear.html
# gear-all.html
# gear-brand.html
# gear-type.html
# new-items.html
# best-sellers.html
# search-results.html?&search_return=all#/?search_return=all&Catalogpdrating=5+Star
# new-items.html
# lifetime-warranty.html
# 2015-10-favorites-landing.html
# gifts-for-kids.html
# 12-best-chargers.html
# wholesale.html
# tel:18607678888
# http://myaccount.batteryjunction.com/
# service.html
# order-status.html
# None

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <script type="text/javascript">
#   <!--
#  (new Image).src="https://store.yahoo.net/cgi-bin/refsd?e=http://www.batteryjunction.com/&h=www.batteryjunction.com&v=1.0&dr=" + escape(document.referrer);
#  -->
#  </script>
#  <head>
#   <title>
#    Batteries, Chargers, LED Flashlights, and More!
#   </title>
#   <meta content="pxdYkxMDpzyq3Z12PoplM0y2HbUwjreq9bx/h+CIrqI=" name="verify-v1"/>
#   <meta content="b60dffc6a31e9863e22b69f54b3c4a06" name="p:domain_verify"/>
#   <meta content="dza6EBMxU6zDpR6PTfftVDP-O8wFLpBFfekVIkqbUis" name="google-site-verification"/>
#   <meta content="LBv7m9AjUZd0CVocANb92wLLhVIBSYaxjuW_SL3vpLI" name="google-site-verification"/>
#   <meta content="CR123A, AA, AAA, C, D and 9V batteries for sale at low prices, and the best chargers and LED flashlights. Lithium, Alkaline &amp; NiMH battery types and more." name="description"/>
#   <meta content="Batteries, Battery Chargers, Flashlights, Solar Products and More! battery, batteries, cr123A, cr123, LED flashlight, search light, tactical light, AA, AAA, C, D, 9V, 18650, fenix, olight, surefire, nitecore, inova, inforce, streamlight, duracell, energizer, rayovac, saft, xeno, terralux, niteize, coast, led lenser, ipower, lithium-ion, li-ion, nimh, nicd, panasonic, tenergy, varta" name="keywords"/>
#   <link href="https://www.batteryjunction.com/" rel="canonical"/>
#   <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/favicon.ico?t=1516228716&amp;" rel="icon" type="image/x-icon"/>
#   <meta content="#0171bb" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=0" name="viewport">
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/ysw-styles.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/owl.carousel.min.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery.fancybox.min.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery.fancybox-thumbs.css?t=1516228716&amp;v=1.0.7" rel="stylesheet" type="text/css"/>
#    <link href="//fonts.googleapis.com/css?family=Open+Sans:400,700,400italic" rel="stylesheet" type="text/css"/>
#    <link href="//fonts.googleapis.com/css?family=Open+Sans+Condensed:300,700" rel="stylesheet" type="text/css"/>
#    <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css" rel="stylesheet"/>
#    <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery-1.11.0.min.js?t=1516228716&amp;">
#    </script>
#    <!--[if lt IE 9]>
# 	<script>
# 		document.createElement('header');
# 		document.createElement('nav');
#                 document.createElement('main');
# 		document.createElement('section');
# 		document.createElement('article');
# 		document.createElement('aside');
# 		document.createElement('footer');
# 	</script>
# <![endif]-->
#    <!--bingads-->
#    <script>
#     (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"5164473"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#    </script>
#    <noscript>
#     <img height="0" src="//bat.bing.com/action/0?ti=5164473&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/>
#    </noscript>
#    <!-- START ABTasty Code for ECI-->
#    <script src="//try.abtasty.com/745834c1dfdfae0ae172eee130580fc3.js" type="text/javascript">
#    </script>
#    <!-- END ABTasty Code for ECI -->
#    <!-- START Pingdom code for RUM-->
#    <script>
#     var _prum = [['id', '59d637f3fbb0e6c0d95b135e'],
# ['mark', 'firstbyte', (new Date()).getTime()]];
# (function() {
# var s = document.getElementsByTagName('script')[0]
# , p = document.createElement('script');
# p.async = 'async';
# p.src = '//rum-static.pingdom.net/prum.min.js';
# s.parentNode.insertBefore(p, s);
# })();
#    </script>
#    <!-- END Pingdom code for RUM -->
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/exclusive-hp-mobile-menu.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/eci-harcode-mobile-floating-menu.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <!-- ECI: Test Desktop Cart Reminder Harcode -->
#    <script src="https://p8.secure.hostingprod.com/@site.batteryjunction.com/ssl/eci_check.php?cartreminder=B&amp;page=store">
#    </script>
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/exclusive-desktop-cart-reminder.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <!-- ECI: Test Desktop Cart Reminder Harcode -->
#    <link href="https://sep.yimg.com/ty/cdn/theshorelinemarket/eci-hc-hp-anchor-links.css?t=1516228716&amp;" rel="stylesheet" type="text/css"/>
#    <!-- ECI: START: Hotjar Tracking Code-->
#    <!-- Hotjar Tracking Code for http://www.batteryjunction.com/ -->
#    <script>
#     (function(h,o,t,j,a,r){
# h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# h._hjSettings={hjid:174065,hjsv:6};
# a=o.getElementsByTagName('head')[0];
# r=o.createElement('script');r.async=1;
# r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#    </script>
#    <!-- ECI:END: Hotjar Tracking Code -->
#   </meta>
#  </head>
#  <body>
#   <header role="banner">
#    <div class="sitewide-promo top" style="color:#fff; background-color:#032E6E;">
#     <span style="font-size:16px; color:#fff; ">
#      <a class="fancybox" data-fancybox-type="iframe" href="free-shipping-popup.html" style="color:#fff;">
#       <strong>
#        FREE SHIPPING
#       </strong>
#       On Orders Over $50
#      </a>
#      *
#     </span>
#    </div>
#    <!-- .sitewide-promo -->
#    <div class="utility-bar">
#     <div class="content-container">
#      <ul class="utility-links">
#       <li>
#        <i class="fa fa-phone">
#        </i>
#        <span>
#         Talk to our Experts:
#         <em>
#          (860) 767-8888
#         </em>
#        </span>
#       </li>
#       <li>
#        <!-- BEGIN TAG CODE - DO NOT EDIT! -->
#        <div id="proactivechatcontainerba9v17m294">
#        </div>
#        <div id="swifttagcontainerba9v17m294">
#         <div id="swifttagdatacontainerba9v17m294" style="display: inline;">
#         </div>
#        </div>
#        <script type="text/javascript">
#         var swiftscriptelemba9v17m294=document.createElement("script");swiftscriptelemba9v17m294.type="text/javascript";var swiftrandom = Math.floor(Math.random()*1001); var swiftuniqueid = "ba9v17m294"; var swifttagurlba9v17m294="https://support.batteryjunction.com/visitor/index.php?...";setTimeout("swiftscriptelemba9v17m294.src=swifttagurlba9v17m294;document.getElementById('swifttagcontainerba9v17m294').appendChild(swiftscriptelemba9v17m294);",1);
#        </script>
#        <!-- END TAG CODE - DO NOT EDIT! -->
#       </li>
#       <li class="customer-service">
#        <a href="service.html">
#         <em>
#          Customer Service
#         </em>
#         <i class="fa fa-angle-down">
#         </i>
#        </a>
#        <div class="cs-dropdown">
#         <ul>
#          <li>
#           <a href="knowledge-center.html">
#            Knowledge Center
#           </a>
#          </li>
#          <li>
#           <a href="service.html">
#            FAQs
#           </a>
#          </li>
#          <li>
#           <a href="order-status.html">
#            Order Status
#           </a>
#          </li>
#          <li>
#           <a href="shipping-info.html">
#            Shipping Information
#           </a>
#          </li>
#          <li>
#           <a href="contact.html">
#            Contact Us
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li>
#        <a href="coupons.html">
#         <i class="fa fa-envelope-o">
#         </i>
#         <em>
#          Sign up
#         </em>
#         for Savings
#        </a>
#       </li>
#       <li>
#        <a href="http://myaccount.batteryjunction.com/">
#         <i class="fa fa-user">
#         </i>
#         <em>
#          Sign in
#         </em>
#         My Account
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- .content-container -->
#    </div>
#    <!-- .utility bar -->
#    <div class="mid-header">
#     <!-- GBD: START- Hardcode Test: 2016.03.29 - Mobile Floating Menu -->
#     <div class="content-container eci_conent_container eci_midheader_floating" style="display:none;">
#      <div class="col1">
#       <div class="mobile-header-menu-btn">
#        <a href="javascript:;">
#         <span class="fa fa-bars">
#         </span>
#        </a>
#       </div>
#      </div>
#      <!-- .col1 -->
#      <div class="col2">
#       <div class="header-search eci-search">
#        <form action="//www.batteryjunction.com/search-results.html" method="get">
#         <input autocomplete="off" class="search-input" name="keywords" placeholder="SEARCH" type="text"/>
#         <input alt="Search" class="search-btn" src="https://sep.yimg.com/ty/cdn/theshorelinemarket/eci-search-icon.jpg?t=1516228716&amp;" type="image"/>
#        </form>
#       </div>
#       <div class="mobile-header-my-account-icon">
#        <a href="http://myaccount.batteryjunction.com/">
#         <span class="fa fa-user">
#         </span>
#        </a>
#       </div>
#       <!-- .header-search -->
#      </div>
#      <!-- .col 2 -->
#      <div class="col3">
#       <div class="floating-cart">
#        <div class="cart-icon">
#        </div>
#        <i class="fa fa-angle-down">
#        </i>
#       </div>
#       <!-- .floating-cart -->
#      </div>
#      <!-- .col3 -->
#     </div>
#     <!-- GBD: END- Harcode Test: 2016.03.29 - Mobile Floating Menu -->
#     <div class="content-container">
#      <div class="col1">
#       <div class="mobile-header-menu-btn">
#        <span class="fa fa-bars">
#        </span>
#       </div>
#       <div class="mobile-header-search-icon">
#        <span class="fa fa-search">
#        </span>
#       </div>
#       <div class="logo">
#        <a href="index.html">
#         <img alt="Battery Junction" src="https://sep.yimg.com/ty/cdn/theshorelinemarket/battery-junction-logo-new.png?t=1516228716&amp;"/>
#        </a>
#       </div>
#       <!-- .logo -->
#       <div class="mobile-header-my-account-icon">
#        <a href="http://myaccount.batteryjunction.com/">
#         <span class="fa fa-user">
#         </span>
#        </a>
#       </div>
#      </div>
#      <!-- .col1 -->
#      <div class="col2">
#       <div class="header-search">
#        <form action="//www.batteryjunction.com/search-results.html" method="get">
#         <input class="search-input" name="keywords" placeholder="Search Keyword or SKU" type="text"/>
#         <input alt="Search" class="search-btn" src="https://sep.yimg.com/ty/cdn/theshorelinemarket/ysw-header-search-btn.png?t=1516228716&amp;" type="image"/>
#        </form>
#       </div>
#       <!-- .header-search -->
#      </div>
#      <!-- .col 2 -->
#      <div class="col3">
#       <div class="floating-cart">
#        <div class="count">
#         (
#         <span>
#          0
#         </span>
#         )
#        </div>
#        <div class="cart-icon">
#        </div>
#        <i class="fa fa-angle-down">
#        </i>
#       </div>
#       <!-- .floating-cart -->
#       <div id="floating-cart" style="display:none;">
#        <p>
#         There are no items in your cart.
#        </p>
#       </div>
#      </div>
#      <!-- .col3 -->
#      <nav role="navigation">
#       <ul class="main-nav">
#        <li>
#         <a href="deals.html">
#          Deals
#         </a>
#         <style>
#          .dealbutton {
#     background-color:#ffffff;
#     border: none;
#     color: #0171bb;
#     padding: 0px 90px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     font-size: 20px;
#     text-transform: uppercase;
#     font-family: "Open Sans   Condensed", sans-serif;
#     border: 2px solid #0171bb;
#     float: right;
# }
# .dealbutton:hover {
#   text-decoration: none;
#   color: #ffffff;
#   background-color: #0171bb;
#   border-color: #0171bb;
# }
# .dealbutton :link {
#   text-decoration: none;
#   color: #012f6d;
# }
# .dealbutton :visited {
#   text-decoration: none;
#   color: #012f6d;
# }
# .buttoncontainer {
#   margin: auto;
#   display: block;
#   max-width: 300px;
#   padding-bottom: 10px;
#   padding-right: 5px;
#   padding-left: 108px;
#   float: right;
# }
# @media screen and (max-width: 1000px) {
#   .dealbutton {
#     max-width: 190px;
#     font-size: 15px;
#     padding-left: 170px;
#     padding-right: 219px;
#     }
#    a.dealbutton {
#     padding-left: 170px !important;
#     padding-right: 220px !important;
#     }
# }
# .category {
#   font-size: 18px;
#   line-height: 18px;
#   padding-bottom: 10px;
# }
# .category a {
#   text-transform: uppercase;
#   color: #0171bb;
#   font-family: "Open Sans Condensed", sans-serif;
# }
# .category a:hover {
#   color: #012f6d;
# }
#         </style>
#         <div class="mega-menu two-col-image">
#          <div class="mm-left">
#           <div class="col">
#            <h2 class="category">
#             <a href="deals.html">
#              Hot Deals
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="klarus-january-promo.html">
#               Klarus Sale
#              </a>
#             </li>
#             <li>
#              <a href="2017-hunting-gear.html">
#               Hunting Headquarters
#              </a>
#             </li>
#             <li>
#              <a href="2017-olight-discounts40.html">
#               Olight Clearance
#              </a>
#             </li>
#             <li>
#              <a href="bargain-bundles.html">
#               Bargain Bundles
#              </a>
#             </li>
#             <li>
#              <a href="clearance.html">
#               Clearance
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#          </div>
#          <!-- .mm-left -->
#          <div class="mm-right">
#           <div class="image">
#            <a href="deals.html">
#             <img alt="Deals Banner" src="https://1dab84c2c05103a7b0db-1e1d21c2e54e342f67cb520004adde98.ssl.cf2.rackcdn.com/2017-7-6NewNavImages/2017-6-30DealsNAV.jpg"/>
#            </a>
#            <div class="buttoncontainer">
#             <a class="dealbutton" href="deals.html" style="padding-left: 150px; padding-right: 172px;">
#              VIEW DEALS
#             </a>
#            </div>
#           </div>
#          </div>
#          <!-- .mm-right -->
#         </div>
#         <!-- .mega menu -->
#        </li>
#        <li>
#         <a href="ln-flashlights.html">
#          Flashlights
#         </a>
#         <style>
#          .flashlightbutton {
#     background-color:#ffffff;
#     border: none;
#     color: #0171bb;
#     padding: 10px 90px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     font-size: 20px;
#     text-transform: uppercase;
#     font-family: "Open Sans   Condensed", sans-serif;
#     border: 2px solid #0171bb;
#     float: right;
# }
# .flashlightbutton:hover {
#   text-decoration: none;
#   color: #ffffff;
#   background-color: #0171bb;
#   border-color: #0171bb;
# }
# .flashlightbutton :link {
#   text-decoration: none;
#   color: #012f6d;
# }
# .flashlightbutton :visited {
#   text-decoration: none;
#   color: #012f6d;
# }
# .buttoncontainer {
#   margin: auto;
#   display: block;
#   max-width: 200px;
#   padding-bottom: 10px;
#   padding-right: 5px;
#   padding-left: 108px;
#   float: right;
# }
# @media screen and (max-width: 1000px) {
#   .flashlightbutton {
#     max-width: 190px;
#     font-size: 15px;
#     padding-left: 44px;
#     padding-right: 140px;
#     }
#    a.flashlightbutton {
#     padding-left: 32px !important;
#     padding-right: 42px !important;
#     }
# }
#         </style>
#         <div class="mega-menu four-col-image">
#          <div class="mm-left">
#           <div class="col">
#            <h2 class="category">
#             <a href="flashlight-brands.html">
#              Brand
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="olt20t15t10.html">
#               Olight
#              </a>
#             </li>
#             <li>
#              <a href="fenix.html">
#               Fenix
#              </a>
#             </li>
#             <li>
#              <a href="surefire.html">
#               SureFire
#              </a>
#             </li>
#             <li>
#              <a href="nitecore.html">
#               Nitecore
#              </a>
#             </li>
#             <li>
#              <a href="jetbeam.html">
#               JETBeam
#              </a>
#             </li>
#             <li>
#              <a href="sunwayled.html">
#               Sunwayman
#              </a>
#             </li>
#             <li>
#              <a href="lightstar-corp.html">
#               LightStar Corp.
#              </a>
#             </li>
#             <li>
#              <a href="klarus.html">
#               Klarus
#              </a>
#             </li>
#             <li>
#              <a href="stfl.html">
#               Streamlight
#              </a>
#             </li>
#             <li>
#              <a href="titanium.html">
#               Titanium Innovations
#              </a>
#             </li>
#             <li>
#              <a href="coast.html">
#               Ledlenser
#              </a>
#             </li>
#             <li>
#              <a href="pelican.html">
#               Pelican
#              </a>
#             </li>
#             <li>
#              <a href="underwater-kinetics-lights.html">
#               Underwater Kinectics
#              </a>
#             </li>
#             <li>
#              <a href="powertac.html">
#               PowerTac
#              </a>
#             </li>
#             <li>
#              <a href="petzl.html">
#               Petzl
#              </a>
#             </li>
#             <li>
#              <a href="asp.html">
#               ASP
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-brands.html">
#               <b>
#                Shop All Brands
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="flashlight-type.html">
#              Type
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="flashlight-edc.html">
#               Every Day Carry
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-head.html">
#               Headlamp
#              </a>
#             </li>
#             <li>
#              <a href="intrinsically-safe-lights.html">
#               Intrinsically Safe
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-key.html">
#               Keychain
#              </a>
#             </li>
#             <li>
#              <a href="lanterns.html">
#               Lantern
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-pen.html">
#               Penlight
#              </a>
#             </li>
#             <li>
#              <a href="rechargeable-.html">
#               Rechargeable
#              </a>
#             </li>
#             <li>
#              <a href="right-angle-flashlights.html">
#               Right Angle
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-search.html">
#               Search
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-tactical.html">
#               Tactical
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-uv.html">
#               Ultra-Violet
#              </a>
#             </li>
#             <li>
#              <a href="weapon-lights.html">
#               Weapon-Mounted
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-accessories.html">
#               Accessories
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-type.html">
#               <b>
#                Shop All Types
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="flashlight-uses.html">
#              Activity
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="bike-lighting.html">
#               Biking
#              </a>
#             </li>
#             <li>
#              <a href="marine-flashlights.html">
#               Boating
#              </a>
#             </li>
#             <li>
#              <a href="camping-flashlights-lanterns.html">
#               Camping
#              </a>
#             </li>
#             <li>
#              <a href="caving-spelunking-flashlights.html">
#               Caving
#              </a>
#             </li>
#             <li>
#              <a href="climbing-flashlights.html">
#               Climbing
#              </a>
#             </li>
#             <li>
#              <a href="dive-lights.html">
#               Diving
#              </a>
#             </li>
#             <li>
#              <a href="hiking-flashlights.html">
#               Hiking
#              </a>
#             </li>
#             <li>
#              <a href="around-the-house-flashlights.html">
#               Household
#              </a>
#             </li>
#             <li>
#              <a href="hunting-flashlights.html">
#               Hunting
#              </a>
#             </li>
#             <li>
#              <a href="law-enforcement-security-flashlights.html">
#               Law Enforcement
#              </a>
#             </li>
#             <li>
#              <a href="photography-flashlights.html">
#               Photography
#              </a>
#             </li>
#             <li>
#              <a href="pilot-flashlights.html">
#               Pilot
#              </a>
#             </li>
#             <li>
#              <a href="running-lights.html">
#               Running
#              </a>
#             </li>
#             <li>
#              <a href="travel-flashlights.html">
#               Travel
#              </a>
#             </li>
#             <li>
#              <a href="light-for-walking-at-night.html">
#               Walking
#              </a>
#             </li>
#             <li>
#              <a href="winter-sports-flashlights.html">
#               Winter Sports
#              </a>
#             </li>
#             <li>
#              <a href="portable-work-lights.html">
#               Work
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-uses.html">
#               <b>
#                Shop All Applications
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="flashlight-power.html">
#              Power Source
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="flashlights-aa.html">
#               AA
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-aaa.html">
#               AAA
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-cr123a.html">
#               CR123A
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-16340.html">
#               16340
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-18650.html">
#               18650
#              </a>
#             </li>
#             <li>
#              <a href="26650-flashlights.html">
#               26650
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-aaaa.html">
#               AAAA
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-cr2.html">
#               CR2
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-c.html">
#               C
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-d.html">
#               D
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-coin.html">
#               Coin Cell
#              </a>
#             </li>
#             <li>
#              <a href="flashlights-packs.html">
#               Battery Pack
#              </a>
#             </li>
#             <li>
#              <a href="sla-flashlights.html">
#               SLA
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-power.html">
#               <b>
#                Shop All Power Sources
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#          </div>
#          <!-- .mm-left -->
#          <div class="mm-right">
#           <div class="image">
#            <a href="flashlight-brands.html">
#             <img alt="Olight R50 Banner" src="https://1dab84c2c05103a7b0db-1e1d21c2e54e342f67cb520004adde98.ssl.cf2.rackcdn.com/2017-7-6NewNavImages/2017-6-30FlashlightsNAV.jpg"/>
#            </a>
#            <div class="buttoncontainer">
#             <a class="flashlightbutton" href="flashlights-all.html" style="padding-left:80px; padding-right: 62px;">
#              VIEW ALL FLASHLIGHTS
#             </a>
#            </div>
#           </div>
#          </div>
#          <!-- .mm-right -->
#         </div>
#         <!-- .mega menu -->
#        </li>
#        <li>
#         <a href="ln-batteries.html">
#          Batteries
#         </a>
#         <style>
#          .batterybutton {
#     background-color:#ffffff;
#     border: none;
#     color: #0171bb;
#     padding: 10px 90px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     font-size: 20px;
#     text-transform: uppercase;
#     font-family: "Open Sans   Condensed", sans-serif;
#     border: 2px solid #0171bb;
#     float: right;
# }
# .batterybutton:hover {
#   text-decoration: none;
#   color: #ffffff;
#   background-color: #0171bb;
#   border-color: #0171bb;
# }
# .batterybutton :link {
#   text-decoration: none;
#   color: #012f6d;
# }
# .batterybutton :visited {
#   text-decoration: none;
#   color: #012f6d;
# }
# .buttoncontainer {
#   margin: auto;
#   display: block;
#   max-width: 200px;
#   padding-bottom: 10px;
#   padding-right: 5px;
#   padding-left: 108px;
#   float: right;
# }
# @media screen and (max-width: 1200px) {
#    a.batterybutton {
#     padding-left: 42px !important;
#     padding-right: 55px !important;
#     }
# }
#         </style>
#         <div class="mega-menu five-col-image">
#          <div class="mm-left">
#           <div class="col">
#            <h2 class="category">
#             <a href="battery-sizes.html">
#              Size
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="batteries-size-cr123a.html">
#               CR123A
#              </a>
#             </li>
#             <li>
#              <a href="18650.html">
#               18650
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-aa.html">
#               AA
#              </a>
#             </li>
#             <li>
#              <a href="aaanireba.html">
#               AAA
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-c.html">
#               C
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-d.html">
#               D
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-9v.html">
#               9V
#              </a>
#             </li>
#             <li>
#              <a href="button-coin-cells.html">
#               Coin Cell
#              </a>
#             </li>
#             <li>
#              <a href="hearing-aid-batteries.html">
#               Hearing Aid
#              </a>
#             </li>
#             <li>
#              <a href="batt-packs.html">
#               Battery Packs
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-16340.html">
#               16340
#              </a>
#             </li>
#             <li>
#              <a href="14500-category.html">
#               14500
#              </a>
#             </li>
#             <li>
#              <a href="10440-category.html">
#               10440
#              </a>
#             </li>
#             <li>
#              <a href="batteries-size-cr2.html">
#               CR2
#              </a>
#             </li>
#             <li>
#              <a href="battery-sizes.html">
#               <b>
#                Shop All Sizes
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="battery-chemistries.html">
#              Chemistry
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="batteries-chemistry-alkaline.html">
#               Alkaline
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-ni-mh.html">
#               NiMh
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-lithium.html">
#               Lithium
#              </a>
#             </li>
#             <li>
#              <a href="liion-cat.html">
#               Li-Ion
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-lithium-thionyl-chloride.html">
#               Lithium Thionyl Chloride
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-li-poly.html">
#               Li-Poly
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-ni-cd.html">
#               NiCd
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-silver-oxide.html">
#               Silver Oxide
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-zinc-air.html">
#               Zinc Air
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-zinc.html">
#               Zinc / Heavy Duty
#              </a>
#             </li>
#             <li>
#              <a href="batteries-chemistry-sla.html">
#               Sealed Lead Acid
#              </a>
#             </li>
#             <li>
#              <a href="battery-chemistries.html">
#               <b>
#                Shop All Chemistries
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="battery-brands.html">
#              Brand
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="batteries-brand-duracell.html">
#               Duracell
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-energizer.html">
#               Energizer
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-panasonic.html">
#               Panasonic
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-tenergy.html">
#               Tenergy
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-titanium.html">
#               Titanium Innovations
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-sony.html">
#               Sony
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-xtar.html">
#               Xtar
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-ultrafire.html">
#               Ultrafire
#              </a>
#             </li>
#             <li>
#              <a href="eneloop-batteries.html">
#               Eneloop
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-maxell.html">
#               Maxell
#              </a>
#             </li>
#             <li>
#              <a href="batteries-brand-rayovac.html">
#               Rayovac
#              </a>
#             </li>
#             <li>
#              <a href="tadiran.html">
#               Tadiran
#              </a>
#             </li>
#             <li>
#              <a href="battery-brands.html">
#               <b>
#                Shop All Brands
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="battery-voltages.html">
#              Voltage
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="batteries-voltage-3v.html">
#               3V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-1v5.html">
#               1.5V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-3v7.html">
#               3.6V / 3.7V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-9v.html">
#               9V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-1v2.html">
#               1.2V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-1v55.html">
#               1.55V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-12v.html">
#               12V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-8v4.html">
#               8.4V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-7v4.html">
#               7.2V / 7.4V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-6v.html">
#               6V
#              </a>
#             </li>
#             <li>
#              <a href="batteries-voltage-9v6.html">
#               9.6V
#              </a>
#             </li>
#             <li>
#              <a href="battery-voltages.html">
#               <b>
#                Shop All Voltages
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="ln-batteries.html">
#              Type
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="primary-batteries.html">
#               Primary
#              </a>
#             </li>
#             <li>
#              <a href="rechargeable-batteries.html">
#               Rechargeable
#              </a>
#             </li>
#             <li>
#              <a href="all-coin-cells.html">
#               Button &amp; Coin Cells
#              </a>
#             </li>
#             <li>
#              <a href="pri-bulk.html">
#               Bulk &amp; Wholesale
#              </a>
#             </li>
#             <li>
#              <a href="baadandca.html">
#               Battery Containers
#              </a>
#             </li>
#             <li>
#              <a href="all-testers.html">
#               Battery Testers &amp; Analyzers
#              </a>
#             </li>
#             <li>
#              <a href="shrink-wrapped-batteries.html">
#               OEM Shrinks
#              </a>
#             </li>
#            </ul>
#            <h2 class="category">
#             <a href="ln-batteries.html">
#              By Product
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="camera-batteries-and-accessories.html">
#               Camera
#              </a>
#             </li>
#             <li>
#              <a href="cell-phone-batteries.html">
#               Cell Phone
#              </a>
#             </li>
#             <li>
#              <a href="defibrillator-batteries.html">
#               Defibrillator
#              </a>
#             </li>
#             <li>
#              <a href="hearing-aid-batteries.html">
#               Hearing Aid
#              </a>
#             </li>
#             <li>
#              <a href="home-security-system-batteries.html">
#               Home Security
#              </a>
#             </li>
#             <li>
#              <a href="remote-control-batteries.html">
#               Remote Control
#              </a>
#             </li>
#             <li>
#              <a href="xfhbattery.html">
#               Xfinity Home Security
#              </a>
#             </li>
#             <li>
#              <a href="ln-batteries.html">
#               <b>
#                See More
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#          </div>
#          <!-- .mm-left -->
#          <div class="mm-right">
#           <div class="image">
#            <a href="tpen-tcr123a-.html">
#             <img alt="Titanium CR123As Banner" src="https://1dab84c2c05103a7b0db-1e1d21c2e54e342f67cb520004adde98.ssl.cf2.rackcdn.com/2017-7-6NewNavImages/2017-6-30BatteriesNAV.jpg"/>
#            </a>
#            <div class="buttoncontainer">
#             <a class="batterybutton" href="batteries-all.html" style="padding-left:80px; padding-right: 90px;">
#              VIEW ALL BATTERIES
#             </a>
#            </div>
#           </div>
#          </div>
#          <!-- .mm-right -->
#         </div>
#         <!-- .mega menu -->
#        </li>
#        <li>
#         <a href="ln-accessories.html">
#          Chargers
#         </a>
#         <style>
#          .chargerbutton {
#     background-color:#ffffff;
#     border: none;
#     color: #0171bb;
#     padding: 10px 90px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     font-size: 20px;
#     text-transform: uppercase;
#     font-family: "Open Sans   Condensed", sans-serif;
#     border: 2px solid #0171bb;
#     float: right;
# }
# .chargerbutton:hover {
#   text-decoration: none;
#   color: #ffffff;
#   background-color: #0171bb;
#   border-color: #0171bb;
# }
# .chargerbutton :link {
#   text-decoration: none;
#   color: #012f6d;
# }
# .chargerbutton :visited {
#   text-decoration: none;
#   color: #012f6d;
# }
# .buttoncontainer {
#   margin: auto;
#   display: block;
#   max-width: 200px;
#   padding-bottom: 10px;
#   padding-right: 5px;
#   padding-left: 108px;
#   float: right;
# }
# @media screen and (max-width: 1000px) {
#   .chargerbutton {
#     max-width: 190px;
#     font-size: 15px;
#     padding-left: 44px;
#     padding-right: 140px;
#     }
#    a.chargerbutton {
#     padding-left: 45px !important;
#     padding-right: 51px !important;
#     }
# }
#         </style>
#         <div class="mega-menu three-col-image">
#          <div class="mm-left">
#           <div class="col">
#            <h2 class="category">
#             <a href="chargers1.html">
#              Battery Chargers
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="12-best-chargers.html">
#               Top 12 Chargers
#              </a>
#             </li>
#             <li>
#              <a href="lithium-chargers.html">
#               Li-Ion Smart Chargers
#              </a>
#             </li>
#             <li>
#              <a href="smchseaaaaac.html">
#               Smart Charger Combos
#              </a>
#             </li>
#             <li>
#              <a href="recrbachrc.html">
#               Li-Ion Charger Combos
#              </a>
#             </li>
#             <li>
#              <a href="cochco.html">
#               Trickle Charger Combos
#              </a>
#             </li>
#             <li>
#              <a href="battery-pack-chargers.html">
#               Battery Pack Chargers
#              </a>
#             </li>
#             <li>
#              <a href="power-banks.html">
#               Power Banks
#              </a>
#             </li>
#             <li>
#              <a href="chargers1.html">
#               <b>
#                Shop All Battery Chargers
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="solarpower.html">
#              Solar
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="sunforce.html">
#               Sunforce
#              </a>
#             </li>
#             <li>
#              <a href="colemansolar.html">
#               Coleman
#              </a>
#             </li>
#             <li>
#              <a href="wagan-solar.html">
#               Wagan
#              </a>
#             </li>
#             <li>
#              <a href="solarpower.html">
#               <b>
#                Shop All Solar
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="charger-accessories.html">
#              Charger Accessories
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="12-accessories.html">
#               12V Power Accessories
#              </a>
#             </li>
#             <li>
#              <a href="plugadapters.html">
#               Travel Plug Adapters
#              </a>
#             </li>
#             <li>
#              <a href="ac11ac22in.html">
#               Voltage Converters
#              </a>
#             </li>
#             <li>
#              <a href="all-testers.html">
#               Battery Testers and Analyzers
#              </a>
#             </li>
#             <li>
#              <a href="ac-wall-chargers.html">
#               AC Wall Chargers
#              </a>
#             </li>
#             <li>
#              <a href="cell-phone-charger.html">
#               Cell Phone Charging Accessories
#              </a>
#             </li>
#             <li>
#              <a href="laptop-power-supplies.html">
#               Laptop Power Supplies
#              </a>
#             </li>
#             <li>
#              <a href="flashlight-chargers.html">
#               Flashlight Chargers
#              </a>
#             </li>
#             <li>
#              <a href="charger-accessories.html">
#               <b>
#                Shop All Charger Accessories
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#          </div>
#          <!-- .mm-left -->
#          <div class="mm-right">
#           <div class="image">
#            <a href="nitecore-d4-digicharger.html">
#             <img alt="Nitecore D4 Charger Banner" src="https://1dab84c2c05103a7b0db-1e1d21c2e54e342f67cb520004adde98.ssl.cf2.rackcdn.com/2017-7-6NewNavImages/2017-6-30ChargersNAV.jpg"/>
#            </a>
#            <div class="buttoncontainer">
#             <a class="chargerbutton" href="chargers-all.html" style="padding-left:93px; padding-right: 77px;">
#              VIEW ALL CHARGERS
#             </a>
#            </div>
#           </div>
#          </div>
#          <!-- .mm-right -->
#         </div>
#         <!-- .mega menu -->
#        </li>
#        <li>
#         <a href="ln-gear.html">
#          Gear
#         </a>
#         <style>
#          .gearbutton {
#     background-color:#ffffff;
#     border: none;
#     color: #0171bb;
#     padding: 0px 90px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     font-size: 20px;
#     text-transform: uppercase;
#     font-family: "Open Sans   Condensed", sans-serif;
#     border: 2px solid #0171bb;
#     float: right;
# }
# .gearbutton:hover {
#   text-decoration: none;
#   color: #ffffff;
#   background-color: #0171bb;
#   border-color: #0171bb;
# }
# .gearbutton :link {
#   text-decoration: none;
#   color: #012f6d;
# }
# .gearbutton :visited {
#   text-decoration: none;
#   color: #012f6d;
# }
# .buttoncontainer {
#   margin: auto;
#   display: block;
#   max-width: 200px;
#   padding-bottom: 10px;
#   padding-right: 5px;
#   padding-left: 108px;
#   float: right;
# }
# @media screen and (max-width: 1000px) {
#   .gearbutton {
#     max-width: 190px;
#     font-size: 15px;
#     padding-left: 44px;
#     padding-right: 140px;
#     }
#    a.gearbutton {
#     padding-left: 74px !important;
#     padding-right: 65px !important;
#     }
# }
#         </style>
#         <div class="mega-menu three-col-image">
#          <div class="mm-left">
#           <div class="col">
#            <h2 class="category">
#             <a href="gear-type.html">
#              Type
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="cutlery.html">
#               Tactical Knives &amp; Tools
#              </a>
#             </li>
#             <li>
#              <a href="bags-and-packs.html">
#               Bags &amp; Packs
#              </a>
#             </li>
#             <li>
#              <a href="protective-storage-case.html">
#               Protective Cases
#              </a>
#             </li>
#             <li>
#              <a href="solar.html">
#               Solar Panels
#              </a>
#             </li>
#             <li>
#              <a href="optics.html">
#               Optics
#              </a>
#             </li>
#             <li>
#              <a href="outdoor-gear.html">
#               Survival Gear
#              </a>
#             </li>
#             <li>
#              <a href="jewelry-cleaning.html">
#               Jewelry Cleaning Supplies
#              </a>
#             </li>
#             <li>
#              <a href="vape-accessories.html">
#               Vaping Accessories
#              </a>
#             </li>
#             <li>
#              <a href="niteite-hard.html">
#               Carabiners &amp; Gear Ties
#              </a>
#             </li>
#             <li>
#              <a href="cell-phone-accessories.html">
#               Cell Phone Accessories
#              </a>
#             </li>
#             <li>
#              <a href="gear-type.html">
#               <b>
#                Shop All Types
#               </b>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- .col -->
#           <div class="col">
#            <h2 class="category">
#             <a href="gear-brand.html">
#              Brand
#             </a>
#            </h2>
#            <ul class="categories">
#             <li>
#              <a href="nipr.html">
#               Nite Ize
#              </a>
#             </li>
#             <li>
#              <a href="wagan.html">
#               Wagan
#              </a>
#             </li>
#             <li>
#              <a href="gunbutter.html">
#               Gun Butter
#              </a>
#             </li>
#             <li>
#              <a href="retrak.html">
#               Retrak
#              </a>
#             </li>
#             <li>
#              <a href="maxpedition-hard-use-gear.html">
#               Maxpedition
#              </a>
#             </li>
#             <li>
#              <a href="underwater-kinetics.html">
#               Underwater Kinetics
#              </a>
#             </li>
#             <li>
#              <a href="pelican-cases.html">
#               Pelican
#              </a>
#             </li>
#             <li>
#              <a href="steripen.html">
#               SteriPen
#              </a>
#             </li>
#             <li>
#              <a href="cyalume-signaling-products.html">
#               Cyalume
#              </a>
#             </li>
#             <li>
#              <a href="gemoro.html">
#               Gemoro
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col">
#            <ul class="categories">
#             <li>
#              <a href="fenix-ruike-tactical-knives-tools.html">
#               Fenix Ruike
#              </a>
#             </li>
#             <li>
#              <a href="ust.html">
#               Ultimate Survival Technologies
#              </a>
#             </li>
#             <li>
#              <a href="revere-liferafts.html">
#               Revere
#              </a>
#             </li>
#             <li>
#              <a href="leatherman.html">
#               Leatherman
#              </a>
#             </li>
#             <li>
#              <a href="sog.html">
#               SOG
#              </a>
#             </li>
#             <li>
#              <a href="colemansolar.html">
#               Coleman
#              </a>
#             </li>
#             <li>
#              <a href="sunforce.html">
#               Sunforce
# ...
#     </li>
#     <li>
#      <a href="ln-gear.html">
#       Gear
#      </a>
#      <div class="menu-level-2-container">
#       <ul class="menu-level-2">
#        <li>
#         <a href="gear-all.html">
#          Shop All Gear
#         </a>
#        </li>
#        <li>
#         <a href="gear-brand.html">
#          Shop By Brand
#         </a>
#        </li>
#        <li>
#         <a href="gear-type.html">
#          Shop By Type
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- .menu-level-2-container -->
#     </li>
#     <li>
#      <a href="new-items.html">
#       New Products
#      </a>
#     </li>
#     <li>
#      <a href="best-sellers.html">
#       Best Sellers
#      </a>
#      <div class="menu-level-2-container">
#       <ul class="menu-level-2">
#        <li>
#         <a href="search-results.html?&amp;search_return=all#/?search_return=all&amp;Catalogpdrating=5+Star">
#          Shop All Best Sellers
#         </a>
#        </li>
#        <li>
#         <a href="new-items.html">
#          Shop New Arrivals
#         </a>
#        </li>
#        <li>
#         <a href="lifetime-warranty.html">
#          Brands with Lifetime Warranties
#         </a>
#        </li>
#        <li>
#         <a href="2015-10-favorites-landing.html">
#          Staff Favorites
#         </a>
#        </li>
#        <li>
#         <a href="gifts-for-kids.html">
#          Gifts For Kids
#         </a>
#        </li>
#        <li>
#         <a href="12-best-chargers.html">
#          Top Chargers
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- .menu-level-2-container -->
#     </li>
#     <li>
#      <a href="wholesale.html">
#       Wholesale
#      </a>
#     </li>
#    </ul>
#    <ul class="info-links">
#     <li>
#      <a href="tel:18607678888">
#       <span class="heading">
#        (860) 767-8888
#       </span>
#       <span class="sub-heading">
#        Talk to our Experts
#       </span>
#      </a>
#     </li>
#     <li>
#      <!-- BEGIN TAG CODE - DO NOT EDIT! -->
#      <div id="proactivechatcontainerbuabg5kgyj">
#      </div>
#      <div id="swifttagcontainerbuabg5kgyj">
#       <div id="swifttagdatacontainerbuabg5kgyj" style="display: inline;">
#       </div>
#      </div>
#      <script type="text/javascript">
#       var swiftscriptelembuabg5kgyj=document.createElement("script");swiftscriptelembuabg5kgyj.type="text/javascript";var swiftrandom = Math.floor(Math.random()*1001); var swiftuniqueid = "buabg5kgyj"; var swifttagurlbuabg5kgyj="https://support.batteryjunction.com/visitor/index.php?...";setTimeout("swiftscriptelembuabg5kgyj.src=swifttagurlbuabg5kgyj;document.getElementById('swifttagcontainerbuabg5kgyj').appendChild(swiftscriptelembuabg5kgyj);",1);
#      </script>
#      <!-- END TAG CODE - DO NOT EDIT! -->
#     </li>
#     <li>
#      <a href="http://myaccount.batteryjunction.com/">
#       <span class="heading">
#        My Account
#       </span>
#      </a>
#     </li>
#     <li>
#      <a href="service.html">
#       <span class="heading">
#        Customer Service
#       </span>
#      </a>
#     </li>
#     <li>
#      <a href="order-status.html">
#       <span class="heading">
#        Track Order
#       </span>
#      </a>
#     </li>
#    </ul>
#   </div>
#   <!-- #mobile-menu -->
#   <a id="mobile-menu-overlay">
#   </a>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery-hoverintent-minified.js?t=1516228716&amp;">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/owl.carousel.min.js?t=1516228716&amp;">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery.fancybox.min.js?t=1516228716&amp;">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/jquery.fancybox-thumbs.js?t=1516228716&amp;v=1.0.7">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/ysw-core-scripts.js?t=1516228716&amp;">
#   </script>
#   <!-- yswLib config and Floating Cart --->
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/yswlib.js?t=1516228716&amp;">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/yswfc.js?t=1516228716&amp;">
#   </script>
#   <script type="text/javascript">
#    yswLib.config('theshorelinemarket','www.batteryjunction.com');
#   </script>
#   <script type="text/javascript">
#    yswFC.go();
#   </script>
#   <!-- ITEM page -->
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/yswitem.js?t=1516228716&amp;">
#   </script>
#   <script src="//nxtcfm.s3.amazonaws.com/eaf58e7cd15bcd057b6d718e82179362-ac.js" type="text/javascript">
#   </script>
#   <script src="//code.jquery.com/ui/1.11.4/jquery-ui.js">
#   </script>
#   <link href="//code.jquery.com/ui/1.11.4/themes/smoothness/jquery-ui.css" property="stylesheet" rel="stylesheet"/>
#   <!-- Bronto Pixel -->
#   <script type="text/javascript">
#    document.write(unescape("%3Cscript src='"
# 		+ ((document.location.protocol == "https:") ? "https:" : "http:")
# 		+ "//p.bm23.com/bta.js' type='text/javascript'%3E%3C/script%3E"));
#   </script>
#   <script type="text/javascript">
#    var bta = new __bta('bmnoryqrrqutjtfdqgibvhydorcmbfb');
# 	bta.setHost("app.bronto.com");
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/ysw-bronto-pixel.js?t=1516228716&amp;">
#   </script>
#   <!--Start Google Remarketing Code-->
#   <script type="text/javascript">
#    var google_tag_params = {ecomm_prodid: 'index',ecomm_pagetype: 'home',};
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */var google_conversion_id = 1070070834;var google_custom_params = window.google_tag_params;var google_remarketing_only = true;var google_conversion_language = "en";var google_conversion_format = "3";/* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1070070834/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!--End Google Remarketing Code-->
#   <script type="text/javascript">
#    var monitus=monitus||{}; monitus.id=1426;monitus.ga_mode=2;
#   </script>
#   <script src="https://c3319586.ssl.cf0.rackcdn.com/js/monitus.js" type="text/javascript">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/exclusive-hp-mobile-menu.js?t=1516228716&amp;">
#   </script>
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/eci-harcode-mobile-floating-menu.js?t=1516228716&amp;">
#   </script>
#   <!-- ECI: Test Desktop Cart Reminder Harcode: Main variation -->
#   <script>
#    jQuery(function(){
#     if (typeof cartpageloaded != "undefined"){ document.cookie = "_eci_cartpage_viewed=1"; }
#     setTimeout(function() {
#  var price = $('div.floating-cart-pricing span.price').text();
# 		if (price != '$0.00') {
#         				if(eciHelpers.Cookie.get('_eci_cartpage_viewed') == '' && eciHelpers.Cookie.get('cartssvalue_watch') != 0 && eciHelpers.Cookie.get('current_user_isactive') != 1) {
# 				var isIE = document.all && document.querySelector && !document.addEventListener;
# 								if (isIE){
# console.log('IE');
# 	$('.cart-reminder').show();
# 				}else{
# console.log('not IE');
# 					$('.cart-reminder').slideDown(500);
# 				}
#
# 			}
#         }
# 	}, 2000);
# });
#   </script>
#   <!-- ECI: Test Desktop Cart Reminder Harcode: Main variation -->
#   <!-- ECI: Test Desktop Cart Reminder Hardcode: Site variation -->
#   <script>
#    if (typeof(eciHelpers) === 'undefined') {
#         var eciHelpers = {};
#     }
#     /*
#      * Cookie Helper Methods
#      */
#     eciHelpers.Cookie = {
#         /**
#          * Set first party cookie for the current domain
#          *
#          * @param name
#          * @param value
#          * @param expires
#          * @param path
#          * @param domain
#          * @param secure
#          */
#         set: function(name, value, expires, path, domain, secure) {
#             if (arguments.length < 2) {
#                 return;
#             }
#             var cookieString = name + "=" + escape(value) + ((path) ? ";path=" + path : ";path=/") +
#                 ((domain) ? ";domain=" + domain : "") + ((secure) ? ";secure" : "");
#             if (!isNaN(parseInt(expires))) {
#                 var dt = new Date();
#                 dt.setDate(dt.getDate() + parseInt(expires));
#                 cookieString += ';expires=' + dt.toGMTString();
#             }
#             document.cookie = cookieString;
#         },
#         /**
#          * Get the cookie value by name..
#          *
#          * @param name
#          * @returns string cookie value
#          */
#         get: function(name) {
#             var nameEQ = name + "=";
#             var ca = document.cookie.split(';');
#             for (var i = 0; i < ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) == ' ') {
#                     c = c.substring(1, c.length);
#                 }
#                 if (c.indexOf(nameEQ) == 0) {
#                     return c.substring(nameEQ.length, c.length);
#                 };
#             }
#             return "";
#         },
#         /**
#          * Delete the cookie..
#          *
#          * @param name
#          */
#         del: function(name) {
#             this.set(name, '', -1);
#         }
#     };
# jQuery(function($){
#            var price = $('div.floating-cart-pricing span.price').text();
#         var eciStieVariation = function() {
#             if (eciHelpers.Cookie.get('cartssvalue_watch') != "1" && price == "$0.00") {
#                 eciHelpers.Cookie.set("cartssvalue_watch", "0", 60 * 60 * 24 * 30 * 1000);
#                 document.cookie = 'current_user_isactive=1';
#             } else {
#                 eciHelpers.Cookie.set("cartssvalue_watch", "1", 60 * 60 * 24 * 30 * 1000);
#             }
#             if (eciHelpers.Cookie.get('cartssvalue_watch') != 0 && eciHelpers.Cookie.get('UserWithCartSaved') != 1 && eciHelpers.Cookie.get('current_user_isactive') != 1) {
#                   eciHelpers.Cookie.set("UserWithCartSaved", "1", 60 * 60 * 24 * 30 * 1000);
#             }
#             $('#ysw-add-to-cart').click(function(event) {
#                 var qty = $('.qty-input');
#                 if (qty.val() == 0) {
#                     return;
#                 }
#                 if (eciHelpers.Cookie.get("cartssvalue_watch") != "1" && qty != 0) {
#                     eciHelpers.Cookie.set("cartssvalue_watch", "1", 60 * 60 * 24 * 30 * 1000);
#                 }
#             });
#         }()
#     //}, 2000);
# })
#   </script>
#   <!-- ECI: Test Desktop Cart Reminder Hardcode: Site variation -->
#   <!-- ECI: Test Desktop Cart Reminder Harcode : Hide Cart Reminder in Mobile and Tablet  -->
#   <style>
#    @media only screen and (max-width: 1024px) {
# .cart-reminder{
# display:none !important;
# }
# }
#   </style>
#   <!-- ECI: Test Desktop Cart Reminder Harcode: Hide Cart Reminder in Mobile and Tablet  -->
#   <!-- pd unified js -->
#   <script src="https://batteryjunction.practicaldatacore.com/cdn/staticJsBlocks/index.js" type="text/javascript">
#   </script>
#   <!-- ****************************************** -->
#   <!-- ********* START PD/ONE TAGGING *********** -->
#   <!-- ****************************************** -->
#   <div categoryid="" id="pdPageTag" productcode="" productid="index" style="display:none">
#   </div>
#   <!-- ****************************************** -->
#   <!-- ********* FINISH PD/ONE TAGGING *********** -->
#   <!-- ****************************************** -->
#   <!-- ************************************************* -->
#   <!-- ********* START PD INTEGRATION SCRIPT *********** -->
#   <!-- ************************************************* -->
#   <script data-cfasync="false" type="text/javascript">
#    function pdInit() {
#
#     //***** REVIEWS IMPLEMENTATION ***********
# 	var elements = document.getElementsByClassName("pdRatingStars");
#     var productIdList = new Array();
#     for(var i=0;i<elements.length;i++) {
#         productIdList[i] = elements[i].getAttribute("productId");
#     }
#     var productIdListCsv = productIdList.join(",");
#
# 	//***** REWARDS IMPLEMENTATION ******
# 	var productIdListRewardsElements = document.getElementsByClassName("pdRewardsPromoMessage");
#     var productIdListRewards = new Array();
#     for(var i=0;i<productIdListRewardsElements.length;i++) {
#         productIdListRewards[i] = productIdListRewardsElements[i].getAttribute("productId");
#     }
#     var productIdListRewardsCsv = productIdListRewards.join(",");
#
# 	//****** CONSTRUCT SCRIPT URL WITH CACHE BUSTING ********************
# 	var cb = (new Date()).getTime();
#     var scriptUrl = "https://batteryjunction.practicaldatacore.com//mod_yahooMerchantSolutions/services/pageScript.php";
#     scriptUrl += "?cb=" + cb;
#     scriptUrl += "&productId=" + encodeURIComponent(document.getElementById("pdPageTag").getAttribute("productId"));
#     scriptUrl += "&productCode=" + encodeURIComponent(document.getElementById("pdPageTag").getAttribute("productCode"));
#     scriptUrl += "&categoryId=" + encodeURIComponent(document.getElementById("pdPageTag").getAttribute("categoryId"));
#     scriptUrl += "&productIdListRewardsCsv=" + encodeURIComponent(productIdListRewardsCsv);
#     scriptUrl += "&productIdListCsv=" + encodeURIComponent(productIdListCsv);
#
#     var scriptElement=document.createElement('script');
#     scriptElement.setAttribute("type","text/javascript");
#     scriptElement.setAttribute("async","async");
#     scriptElement.setAttribute("src", scriptUrl);
#     document.body.appendChild(scriptElement);
#
# }
# pdInit();
#   </script>
#   <!-- ************************************************** -->
#   <!-- ********* FINISH PD INTEGRATION SCRIPT *********** -->
#   <!-- ************************************************** -->
#   <script src="https://sep.yimg.com/ty/cdn/theshorelinemarket/yswBrontoTracker.js?t=1516228716&amp;">
#   </script>
#   <script>
#    yswBrontoTracker.url = 'https://www.batteryjunction.com';
# yswBrontoTracker.yahooid = 'theshorelinemarket';
# yswBrontoTracker.go();
#   </script>
#   <script data-name="__br_tm" type="text/javascript">
#    var _bsw = _bsw || [];
#   _bsw.push(['_bswId', 'a0bee7cc84b1fdfe6fcef26657b8c726678c983411fe5283e6257bb9bc2d8bdd']);
#   (function() {
#     var bsw = document.createElement('script'); bsw.type = 'text/javascript'; bsw.async = true;
#     bsw.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'js.bronto.com/c/77zzz088hgc7vga9jx5q5n810fjc4zrh8phrhzrnpgxqhv7a80/a0bee7cc84b1fdfe6fcef26657b8c726678c983411fe5283e6257bb9bc2d8bdd/s/b.min.js';
#     var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(bsw, t);
#   })();
#   </script>
#   <!-- Exclusive Concepts Script - DO NOT REMOVE OR MOVE -->
#   <!--- Conversions On Demand script, more info at https://www.conversionsondemand.com - Do Not Remove or Replace -->
#   <script type="text/javascript">
#    // <![CDATA[
#     var cod_page_guid = 'NON-PRODUCT';
#     var COD_CONFIG = {'platform':'ys', 'stoken':'batteryjunction_com'};
#         (function(){
#             var divCOD = document.createElement('div');
#             divCOD.id = 'codScripts';
#             var bodytag = document.getElementsByTagName('body')[0];
#             bodytag.appendChild(divCOD);
#             var cod = document.createElement('script');
#             cod.type = 'text/javascript';
#             cod.src = 'https://www.conversionsondemand.com/codadmin2/framework/cod-scripts-loader.js';
#             var s = document.getElementById('codScripts');
#             s.parentNode.insertBefore(cod, s);
#         })(COD_CONFIG);
# // ]]>
#   </script>
#   <!--- Conversions On Demand script, more info at https://www.conversionsondemand.com - Do Not Remove or Replace -->
#  </body>
#  <script type="text/javascript">
#   csell_env = 'bf1';
#  var storeCheckoutDomain = 'order.store.yahoo.net';
#  </script>
#  <script type="text/javascript">
#   (function (d, w) { var f = function () { var x = d.getElementsByTagName('SCRIPT')[0]; var s = d.createElement('SCRIPT'); s.type = 'text/javascript'; s.async = true; s.src = '//np.lexity.com/embed/YA/94b908889998294b7e52adb36e3c128e?id=2e0011b91467'; x.parentNode.insertBefore(s, x); }; w.attachEvent ? w.attachEvent('onload',f) : w.addEventListener('load',f,false); }(document, window));
#  </script>
# </html>

# %%
div_element = soup.find('div', attrs ={'class': 'cart-reminder'})

# %%
print(div_element.text.strip())
# Out:
# Welcome back! We saved your shopping cart for you:
#
# View Cart

# %%
print(div_element)
# Out:
# <div class="cart-reminder">
#         Welcome back! We saved your shopping cart for you:
#         <a href="http://order.store.yahoo.net/theshorelinemarket/cgi-bin/wg-order?theshorelinemarket">
# View Cart
# </a>
# </div>

# %%
link = div_element.find('a')

# %%
print(link.get('href'))
# Out:
# http://order.store.yahoo.net/theshorelinemarket/cgi-bin/wg-order?theshorelinemarket

# %%
print(div_element.text)
# Out:
#         Welcome back! We saved your shopping cart for you:
#
# View Cart

# %%
name_and_price = soup.find_all('div', {"class" : "details"})

# %%
for item in name_and_price:
    name = item.find('h2').text
    link = item.find('a')
    link = link.get('href')
    price = item.find('div', {"class": "price"})
    price = price.text
    print(name , link, price)
# Out:
# Olight PL1 II Valkyrie LED Pistol Light - Picatinny and Glock Rails - CREE XP-L CW LED - 450 Lumens - Includes 1 x CR123A
#  olight-valkyrie.html
# $59.95
#
#
# Nitecore EC23 LED Flashlight - CREE XHP35 HD E2 - 1800 Lumens - Uses 1 x IMR 18650 or 2 x CR123As
#  nitecore-ec23-led-flashlight.html
# $54.95
#
#
# Nitecore HC60 USB Rechargeable Headlamp - CREE XM-L2 U2 LED - 1000 Lumens - Uses 1 x 18650 (Included) or 2 x CR123As
#  nitecore-hc60-headlamp.html
# $59.95
#
#
# Sunwayman T20CC USB Rechargeable Tri-Color Tactical Flashlight - CREE XM-L2 U3 White LED - Red, Green and UV Outputs - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A - Black or Gray
#  sunwayman-t20cc-opt.html
# $79.00
#
#
# Klarus XT2CR Rechargeable Tactical Flashlight - CREE XHP35 HD E4 - 1600 Lumens - Uses 1 x 18650 (included) or 2 x CR123A
#  klarus-xt2cr-tactical-flashlight.html
# $74.95
#
#
# Olight M2R Warrior Rechargeable Pocket-Friendly Tactical Flashlight - CREE XHP35 HD LED - Cool White or Neutral White - 1500 Lumens - Uses 1 x 18650 (Included) or 2 x CR123As
#  olight-m2r-tactical-led-flashlight.html
# $99.95
#
#
# Klarus Mini One Ti Micro-USB Rechargeable LED Keychain Flashlight - CREE XP-G3 - 130 Lumens - Titanium - Includes 1 x 10180
#  klarus-mini-one-ti-keychain-light.html
# $39.95
#
#
# Klarus XT11GT HD Rechargeable Tactical Flashlight - CREE XHP35 HD E4 LED - 2000 Lumens - Uses 2 x CR123A  or 1 x 18650 (Included)
#  klarus-xt11gt-hd-flashlight.html
# $89.95
#
#
# Olight S30R Baton III USB Rechargeable Flashlight - CREE XM-L2 LED - 1050 Lumens - Includes 1 x 18650
#  olight-s30r-iii.html
# $79.95
#
#
# Fenix HL40R Rechargeable Focusable LED Headlamp - CREE XP-L HI V2 LED - 600 Lumens - Includes Built-In Li-Poly Battery Pack - Blue or Grey
#  fenix-hl40r-focusable-led-headlamp.html
# $59.95
#
#
# Nitecore TINI USB Rechargeable LED Key Light - CREE XP-G2 S3 LED - 380 Lumens - Includes 1 x Li-Ion Battery Pack
#  nitecore-tini.html
# $29.99
#
#
# Duracell Procell PC1500 AA 1.5V Alkaline Button Top Battery - Contractor Pack, Priced Per Cell
#  pc-1500.html
# $0.45
#
#
# Titanium Innovations 9V 1200mAh Lithium Primary (LiMnO2) Battery - 1pc Retail Card - Snap Connectors (CR9V-1PK)
#  titanium-innovations-9-volt-lithium-1pk.html
# $4.99
#
#
# Energizer Ultimate L91 AA 3000mAh 1.5V High Energy 5A Lithium (LiFeS2) Button Top Batteries - Bulk
#  energizer-l91aa.html
# $1.60
#
#
# Sony CR2032 220mAh 3V Lithium (LiMnO2) Coin Cell Watch Battery - 1 Piece Tear Strip, Sold Individually
#  cr2032.html
# $0.80
#
#
# Energizer ECR1632 130mAh 3V Lithium (LiMNO2) Coin Cell Battery - 1 Piece Tear Strip, Sold Individually
#  energizer-ecr1632.html
# $1.10
#
#
# Duracell Ultra DL CR123A 1470mAh 3V Lithium (LiMNO2) Button Top Photo Battery - Bulk
#  duraacell-cr123a.html
# $1.90
#
#
# Energizer ECR2032 240mAh 3V Lithium (LiMNO2) Coin Cell Battery - 1 Piece Tear Strip, Sold Individually
#  encocebaeccr4.html
# $1.00
#
#
# Duracell Duralock MN2400 AAA 1.5V Alkaline Button Top Battery - Made in China - Bulk
#  mn-2400.html
# $0.40
#
#
# Energizer ECR2450-BP-1 620mAh 3V Lithium Primary (LiMNO2) Coin Cell Battery - 1 Piece Blister Pack
#  energizer-ecr2450bp.html
# $1.47
#
#
# Pelican U105 Urban Laptop Backpack
#  pelican-0u1050-0003-110.html
# $65.95
#
#
# SOG PowerAssist Multi-Tool - Includes 12 Tools - Black Oxide (B66N) or Satin (S66N) Finish - Nylon Sheath
#  sog-b66-n.html
# $66.97
#
#
# Nitecore Lifesaving Emergency Titanium Whistle NWS10 - 120db
#  nitecore-nws10.html
# $20.00
#
#
# Ultimate Survival Technologies Deluxe Map Compass / Route Planning Tool - Liquid-Filled Compass with Measuring Scales - Clear (20-310-455C)
#  ust-20-310-455c.html
# $3.95
#
#
# Ultimate Survival Technologies Folding Scissors - Stainless Steel (20-310-173)
#  ust-20-310-173.html
# $2.00
#
#
# Titanium Innovations High Viz Reflective Safety Belt
#  safety-belt.html
# $2.95
#
#
# Nitecore BP20 Multi-Purpose Backpack - 20L - Black
#  nitecore-bp20-multi-purpose-backpack.html
# $69.95
#
#
# Ultimate Survival Technologies Paper Pad with Pencil - 3 x 5-inch Tear-Proof and Waterproof 50-Page Notebook (20-310-116)
#  ust-20-310-116.html
# $3.25
#
#
# Ultimate Survival Technologies Survival Bandana with Survival Tips - 22 x 22-inch - High-Visibility Orange (20-PGR0001-08)
#  ust-20-pgr0001-08.html
# $2.00
#
#
# Fenix TK25 Red LED Flashlight - CREE XP-G2 LED - CREE XP-E2 Red LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A
#  fenix-tk25-red-led-flashlight.html
# $89.95
#
#
# Fenix TK35UE 2018 Ultimate Edition Multi-Functional Flashlight - CREE XHP70 LED - 3200 Lumens - Uses 2 x 18650
#  fenix-tk35ue-multi-functional-led-flashlight.html
# $139.95
#
#
# Sunwayman C41CT Rechargeable LED Flashlight - CREE XM-L2 U3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A
#  sunwayman-c41ct-rechargeable-led-flashlight.html
# $59.00
#
#
# Nitecore HC65 Rechargeable LED Headlamp - CREE XM-L2 U2 - 1000 Lumens - Uses 1 x 18650 (included)
#  nitecore-hc65-led-headlamp.html
# $74.95
#
#
# Olight S1 MINI Baton EDC Flashlight - CREE XM-L2 CW LED - 600 Lumens - Includes 1 x 16340 RCR123A
#  olight-s1-mini-baton-edc-flashlight.html
# $49.95
#
#
# Fenix HL32R Rechargeable LED Headlamp - CREE XP-G3 and Nichia Red LED - 600 Lumens - Uses Built-In 2000mAh Li-Poly Battery Pack
#  fenix-hl32r-rechargeable-headlamp.html
# $54.95
#
#
# JETBeam SF-AA01 EDC Flashlight - 1 x CREE XP-L HI LED - 700 Lumens - Uses 1 x AA or 1 x 14500 (Available Add-on!)
#  jetbeam-sf-aa01-edc-flashlight.html
# $36.45
#
#
# Klarus ST10 Rechargeable LED Flashlight - CREE XM-L2 U2 LED - 1100 Lumens - Uses 1 x 18650 (included) or 2 x CR123A
#  klarus-st10-rechargeable-led-flashlight.html
# $44.95
#
#
# Titanium Innovations 9V 1200mAh Lithium Primary (LiMnO2) Battery - 10 Pack Contractor Pack - Snap Connectors (CR9V-BX10)
#  titanium-innovations-9-volt-lithium-10-box.html
# $49.00

# %%
import csv
from datetime import datetime

# %%
with open('index.csv', 'a') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow([name, link, price, datetime.now()])

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
from urllib.request import HTTPError

html = urlopen('https://www.batteryjunction.com/')
soup = BeautifulSoup(html, 'html.parser')

name_and_price = soup.find_all('div', {"class" : "details"})

import csv
from datetime import datetime

# %%
for item in name_and_price:
    name = item.find('h2').text
    link = item.find('a')
    link = link.get('href')
    price = item.find('div', {"class": "price"})
    price = price.text
    print(name, price, link)
    with open('index.csv', 'a') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow([name, price, link, datetime.now()])
# Out:
# Olight PL1 II Valkyrie LED Pistol Light - Picatinny and Glock Rails - CREE XP-L CW LED - 450 Lumens - Includes 1 x CR123A
#
# $59.95
#                  olight-valkyrie.html
#
# Nitecore EC23 LED Flashlight - CREE XHP35 HD E2 - 1800 Lumens - Uses 1 x IMR 18650 or 2 x CR123As
#
# $54.95
#                  nitecore-ec23-led-flashlight.html
#
# Nitecore HC60 USB Rechargeable Headlamp - CREE XM-L2 U2 LED - 1000 Lumens - Uses 1 x 18650 (Included) or 2 x CR123As
#
# $59.95
#                  nitecore-hc60-headlamp.html
#
# Sunwayman T20CC USB Rechargeable Tri-Color Tactical Flashlight - CREE XM-L2 U3 White LED - Red, Green and UV Outputs - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A - Black or Gray
#
# $79.00
#                  sunwayman-t20cc-opt.html
#
# Klarus XT2CR Rechargeable Tactical Flashlight - CREE XHP35 HD E4 - 1600 Lumens - Uses 1 x 18650 (included) or 2 x CR123A
#
# $74.95
#                  klarus-xt2cr-tactical-flashlight.html
#
# Olight M2R Warrior Rechargeable Pocket-Friendly Tactical Flashlight - CREE XHP35 HD LED - Cool White or Neutral White - 1500 Lumens - Uses 1 x 18650 (Included) or 2 x CR123As
#
# $99.95
#                  olight-m2r-tactical-led-flashlight.html
#
# Klarus Mini One Ti Micro-USB Rechargeable LED Keychain Flashlight - CREE XP-G3 - 130 Lumens - Titanium - Includes 1 x 10180
#
# $39.95
#                  klarus-mini-one-ti-keychain-light.html
#
# Klarus XT11GT HD Rechargeable Tactical Flashlight - CREE XHP35 HD E4 LED - 2000 Lumens - Uses 2 x CR123A  or 1 x 18650 (Included)
#
# $89.95
#                  klarus-xt11gt-hd-flashlight.html
#
# Olight S30R Baton III USB Rechargeable Flashlight - CREE XM-L2 LED - 1050 Lumens - Includes 1 x 18650
#
# $79.95
#                  olight-s30r-iii.html
#
# Fenix HL40R Rechargeable Focusable LED Headlamp - CREE XP-L HI V2 LED - 600 Lumens - Includes Built-In Li-Poly Battery Pack - Blue or Grey
#
# $59.95
#                  fenix-hl40r-focusable-led-headlamp.html
#
# Nitecore TINI USB Rechargeable LED Key Light - CREE XP-G2 S3 LED - 380 Lumens - Includes 1 x Li-Ion Battery Pack
#
# $29.99
#                  nitecore-tini.html
#
# Duracell Procell PC1500 AA 1.5V Alkaline Button Top Battery - Contractor Pack, Priced Per Cell
#
# $0.45
#                  pc-1500.html
#
# Titanium Innovations 9V 1200mAh Lithium Primary (LiMnO2) Battery - 1pc Retail Card - Snap Connectors (CR9V-1PK)
#
# $4.99
#                  titanium-innovations-9-volt-lithium-1pk.html
#
# Energizer Ultimate L91 AA 3000mAh 1.5V High Energy 5A Lithium (LiFeS2) Button Top Batteries - Bulk
#
# $1.60
#                  energizer-l91aa.html
#
# Sony CR2032 220mAh 3V Lithium (LiMnO2) Coin Cell Watch Battery - 1 Piece Tear Strip, Sold Individually
#
# $0.80
#                  cr2032.html
#
# Energizer ECR1632 130mAh 3V Lithium (LiMNO2) Coin Cell Battery - 1 Piece Tear Strip, Sold Individually
#
# $1.10
#                  energizer-ecr1632.html
#
# Duracell Ultra DL CR123A 1470mAh 3V Lithium (LiMNO2) Button Top Photo Battery - Bulk
#
# $1.90
#                  duraacell-cr123a.html
#
# Energizer ECR2032 240mAh 3V Lithium (LiMNO2) Coin Cell Battery - 1 Piece Tear Strip, Sold Individually
#
# $1.00
#                  encocebaeccr4.html
#
# Duracell Duralock MN2400 AAA 1.5V Alkaline Button Top Battery - Made in China - Bulk
#
# $0.40
#                  mn-2400.html
#
# Energizer ECR2450-BP-1 620mAh 3V Lithium Primary (LiMNO2) Coin Cell Battery - 1 Piece Blister Pack
#
# $1.47
#                  energizer-ecr2450bp.html
#
# Pelican U105 Urban Laptop Backpack
#
# $65.95
#                  pelican-0u1050-0003-110.html
#
# SOG PowerAssist Multi-Tool - Includes 12 Tools - Black Oxide (B66N) or Satin (S66N) Finish - Nylon Sheath
#
# $66.97
#                  sog-b66-n.html
#
# Nitecore Lifesaving Emergency Titanium Whistle NWS10 - 120db
#
# $20.00
#                  nitecore-nws10.html
#
# Ultimate Survival Technologies Deluxe Map Compass / Route Planning Tool - Liquid-Filled Compass with Measuring Scales - Clear (20-310-455C)
#
# $3.95
#                  ust-20-310-455c.html
#
# Ultimate Survival Technologies Folding Scissors - Stainless Steel (20-310-173)
#
# $2.00
#                  ust-20-310-173.html
#
# Titanium Innovations High Viz Reflective Safety Belt
#
# $2.95
#                  safety-belt.html
#
# Nitecore BP20 Multi-Purpose Backpack - 20L - Black
#
# $69.95
#                  nitecore-bp20-multi-purpose-backpack.html
#
# Ultimate Survival Technologies Paper Pad with Pencil - 3 x 5-inch Tear-Proof and Waterproof 50-Page Notebook (20-310-116)
#
# $3.25
#                  ust-20-310-116.html
#
# Ultimate Survival Technologies Survival Bandana with Survival Tips - 22 x 22-inch - High-Visibility Orange (20-PGR0001-08)
#
# $2.00
#                  ust-20-pgr0001-08.html
#
# Fenix TK25 Red LED Flashlight - CREE XP-G2 LED - CREE XP-E2 Red LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A
#
# $89.95
#                  fenix-tk25-red-led-flashlight.html
#
# Fenix TK35UE 2018 Ultimate Edition Multi-Functional Flashlight - CREE XHP70 LED - 3200 Lumens - Uses 2 x 18650
#
# $139.95
#                  fenix-tk35ue-multi-functional-led-flashlight.html
#
# Sunwayman C41CT Rechargeable LED Flashlight - CREE XM-L2 U3 LED - 1000 Lumens - Uses 1 x 18650 or 2 x CR123A
#
# $59.00
#                  sunwayman-c41ct-rechargeable-led-flashlight.html
#
# Nitecore HC65 Rechargeable LED Headlamp - CREE XM-L2 U2 - 1000 Lumens - Uses 1 x 18650 (included)
#
# $74.95
#                  nitecore-hc65-led-headlamp.html
#
# Olight S1 MINI Baton EDC Flashlight - CREE XM-L2 CW LED - 600 Lumens - Includes 1 x 16340 RCR123A
#
# $49.95
#                  olight-s1-mini-baton-edc-flashlight.html
#
# Fenix HL32R Rechargeable LED Headlamp - CREE XP-G3 and Nichia Red LED - 600 Lumens - Uses Built-In 2000mAh Li-Poly Battery Pack
#
# $54.95
#                  fenix-hl32r-rechargeable-headlamp.html
#
# JETBeam SF-AA01 EDC Flashlight - 1 x CREE XP-L HI LED - 700 Lumens - Uses 1 x AA or 1 x 14500 (Available Add-on!)
#
# $36.45
#                  jetbeam-sf-aa01-edc-flashlight.html
#
# Klarus ST10 Rechargeable LED Flashlight - CREE XM-L2 U2 LED - 1100 Lumens - Uses 1 x 18650 (included) or 2 x CR123A
#
# $44.95
#                  klarus-st10-rechargeable-led-flashlight.html
#
# Titanium Innovations 9V 1200mAh Lithium Primary (LiMnO2) Battery - 10 Pack Contractor Pack - Snap Connectors (CR9V-BX10)
#
# $49.00
#                  titanium-innovations-9-volt-lithium-10-box.html

# %%
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-612ef00a7e75> in <module>()
# ----> 1 import selenium
#
# ModuleNotFoundError: No module named 'selenium'
